# %%
'''
The following script is used to remove duplicate images in the data set
The way to detect duplicate image is to check if the hash value of two images are the same
Note that the changes are performed in place,
so please make sure you have a copy of the csv file and the image folder to "undo" the process
'''
# the csv file and the image folder to remove duplicate
TARGET_CSV_FILE = r"C:\Users\jdu12\Desktop\humpback\train.csv"
TARGET_IMG_PATH = r"C:\Users\jdu12\Desktop\humpback\train"

# %%
import numpy as np
import pandas as pd
from PIL import Image
import imagehash
import collections
import os

def getImageHash(imagePath):
    """
    Fuction to calculate the image's hash value given the image path
    
    Args:
        imagePath: the path to the image
    Returns:
        str: hash value of the image.
    """
    with Image.open(imagePath) as img:
        imgHash = imagehash.phash(img)
        return str(imgHash)

def get_train_input(targetCSVFile, targetImageFolder):
    """
    Fuction to load the CSV file and append the hash value of the corresponding images
    
    Args:
        targetCSVFile: the path to the CSV file
        targetImageFolder: the folder of the images

    Returns:
        pandas.DataFrame: data of the CSV with index (autoincrement); Image (filename); Id (label); Hash
    """
    train_input = pd.read_csv(targetCSVFile)
    
    imgHashes = train_input.Image.apply(lambda imageFile: getImageHash(os.path.join(targetImageFolder,imageFile)))
    train_input["Hash"] = [hashValue for hashValue in imgHashes]
    
    return train_input

def getHashWithDuplicate(dataWithHash):
    hashAndCounts = dataWithHash.Hash.value_counts()
    return hashAndCounts.loc[hashAndCounts>1]

def showDuplicateData(dataWithHash, ignoredNewWhale = True):
    """
    Fuction to show duplicate data in the dataset (duplicate images with different labels)
    
    Args:
        dataWithHash: data obtained from get_train_input (included hash value)
        ignoredNewWhale: the folder of the images
    """
    hashWithDuplicate = getHashWithDuplicate(dataWithHash)
    
    newWhaleCount = 0
    numOfDuplicate = 0
    _numOfDuplicate = 0
    for hashValue in hashWithDuplicate.index:
        duplicatedInfo = train_input[train_input.Hash==hashValue]
        shownId = set(duplicatedInfo.Id)
        
        numOfDuplicate = numOfDuplicate + (len(duplicatedInfo)-len(shownId))
        _numOfDuplicate = _numOfDuplicate + len(duplicatedInfo)
        if 'new_whale' in shownId:
            newWhaleCount += 1
            numOfDuplicate -= 1
        if ignoredNewWhale:
            shownId.discard('new_whale')
            
        if len(shownId) >= 1:
            print("Duplicate images: {}, set of Ids: {}".format(duplicatedInfo.Image.tolist(), shownId))
    if not ignoredNewWhale:
        print("Number of 'new whale' in duplicate images: {}".format(newWhaleCount))
    print("Number of duplicates: {}".format(numOfDuplicate))
    print("Number of _duplicates: {}".format(_numOfDuplicate))
            
def inconsistentDataIndex(dataWithHash, newWhaleOnly = True):
    """
    Fuction to show inconsistent data in the dataset (duplicate images with different labels)
    
    Args:
        dataWithHash: data obtained from get_train_input (included hash value)
        ignoredNewWhale: the folder of the images

    Returns:
        pandas.DataFrame: data of the CSV with index (autoincrement); Image (filename); Id (label); Hash
    """
    hashWithDuplicate = getHashWithDuplicate(dataWithHash)
    
    targetList = []
    for hashValue in hashWithDuplicate.index:
        duplicatedInfo = train_input[(train_input.Hash==hashValue) & ((train_input.Id == 'new_whale') | (not newWhaleOnly))]
        
        if len(duplicatedInfo.index.values)>0:
            targetList += duplicatedInfo.index.values.tolist()
    return targetList

def removeInconsistentData(dataWithHash, targetCSVFile, targetImageFolder, newWhaleOnly = True):
    rowIndices = inconsistentDataIndex(dataWithHash, newWhaleOnly)
    
    # remove images
    for imagePath in dataWithHash.loc[dataWithHash.index.isin(toRemove)].Image.tolist():
        os.remove(os.path.join(targetImageFolder, imagePath))
    
    # drop rows in CSV
    dataWithHash.drop(rowIndices, inplace=True)
    dataWithHash.to_csv(targetCSVFile, index=False, columns=['Image', 'Id'])

def removeDuplicateData(dataWithHash, targetCSVFile, targetImageFolder):
    # remove images
    for imagePath in dataWithHash[dataWithHash.duplicated(subset=['Id','Hash'], keep='first')].Image.tolist():
        os.remove(os.path.join(targetImageFolder, imagePath))
    
    # drop rows in CSV
    dataWithHash.drop_duplicates(subset=['Id','Hash'], keep='first', inplace=True)
    dataWithHash.to_csv(targetCSVFile, index=False, columns=['Image', 'Id'])

# %%
train_input = get_train_input(TARGET_CSV_FILE, TARGET_IMG_PATH)

# %%
showDuplicateData(train_input, False)
# Out:
# Duplicate images: ['59becb6c.jpg', 'cc68d9f2.jpg', 'eb026a29.jpg'], set of Ids: {'w_cae7677', 'new_whale'}
# Duplicate images: ['7b738ee1.jpg', 'c0785cd9.jpg'], set of Ids: {'w_5c23454'}
# Duplicate images: ['f1b7c15c.jpg', 'ff2d0d82.jpg'], set of Ids: {'w_17ee910', 'new_whale'}
# Duplicate images: ['2985c2ae.jpg', '36c04f89.jpg'], set of Ids: {'w_49bbc79'}
# Duplicate images: ['4123189d.jpg', '637b28a7.jpg'], set of Ids: {'w_efd3f81', 'new_whale'}
# Duplicate images: ['b15a5565.jpg', 'f78d5e9e.jpg'], set of Ids: {'w_db7e2c5'}
# Duplicate images: ['54d52fe1.jpg', 'db0c4225.jpg'], set of Ids: {'w_5e25f9f'}
# Duplicate images: ['3b1a143a.jpg', 'd7f63ee6.jpg'], set of Ids: {'w_dc81791'}
# Duplicate images: ['e2e68da4.jpg', 'fa29b1d9.jpg'], set of Ids: {'w_06a6351'}
# Duplicate images: ['9d4ec8e6.jpg', 'a9827190.jpg'], set of Ids: {'w_a837660'}
# Duplicate images: ['27627742.jpg', '36118167.jpg'], set of Ids: {'w_fd3ce71', 'new_whale'}
# Duplicate images: ['490d05ea.jpg', 'f2d9b75f.jpg'], set of Ids: {'w_4a38a9f'}
# Duplicate images: ['4f340f53.jpg', 'a12b8b1d.jpg'], set of Ids: {'w_351a1e1'}
# Duplicate images: ['319d0748.jpg', 'e54247f6.jpg'], set of Ids: {'w_7417ab0'}
# Duplicate images: ['5a1a5598.jpg', 'c9cb9974.jpg'], set of Ids: {'w_4848a3c'}
# Duplicate images: ['2ed2d780.jpg', 'bc773132.jpg'], set of Ids: {'w_f4e03d4'}
# Duplicate images: ['8d19395a.jpg', '90acceb8.jpg'], set of Ids: {'w_d88da6d', 'new_whale'}
# Duplicate images: ['77be4e0a.jpg', 'aba5de33.jpg'], set of Ids: {'w_616ca36'}
# Duplicate images: ['3cfd2219.jpg', '954ff001.jpg'], set of Ids: {'w_bf77b13'}
# Duplicate images: ['23f9ba33.jpg', '5f6ca2ec.jpg'], set of Ids: {'w_d9aab0a'}
# Duplicate images: ['0df9e124.jpg', 'b5661447.jpg'], set of Ids: {'w_3c2ec7a'}
# Duplicate images: ['497fb93e.jpg', 'e1210d76.jpg'], set of Ids: {'w_fe5e78b'}
# Duplicate images: ['200b53a2.jpg', '6fc557ed.jpg'], set of Ids: {'w_aa16da4', 'new_whale'}
# Duplicate images: ['0d482f6b.jpg', 'ab7916f7.jpg'], set of Ids: {'w_28ce17c', 'new_whale'}
# Duplicate images: ['422d9bfd.jpg', 'be111ce5.jpg'], set of Ids: {'w_3e0f25d'}
# Duplicate images: ['5eb99fc2.jpg', '6cbbeedd.jpg'], set of Ids: {'w_8044362'}
# Duplicate images: ['a66f85c4.jpg', 'd661937a.jpg'], set of Ids: {'w_f86488a'}
# Duplicate images: ['37404a88.jpg', '51cd62cd.jpg'], set of Ids: {'w_2f54c3c'}
# Duplicate images: ['b73c4390.jpg', 'fd176ee0.jpg'], set of Ids: {'w_15eae33'}
# Duplicate images: ['16f0ccef.jpg', '75011de3.jpg'], set of Ids: {'w_92585eb'}
# Duplicate images: ['30ea3bfe.jpg', 'b28cc478.jpg'], set of Ids: {'w_88f57d0', 'new_whale'}
# Duplicate images: ['3450cdef.jpg', '91699de9.jpg'], set of Ids: {'w_d88328d'}
# Duplicate images: ['0344cc34.jpg', '2af4d9b7.jpg'], set of Ids: {'w_fea7fe6'}
# Duplicate images: ['b5f01672.jpg', 'ed284e79.jpg'], set of Ids: {'w_1287fbc'}
# Duplicate images: ['66a4f9b9.jpg', '7569566d.jpg'], set of Ids: {'w_048f7a9'}
# Duplicate images: ['508958a1.jpg', 'adce1628.jpg'], set of Ids: {'w_22bb9b3', 'new_whale'}
# Duplicate images: ['024144e5.jpg', 'e17384fd.jpg'], set of Ids: {'w_0f16be3', 'new_whale'}
# Duplicate images: ['5efb5870.jpg', 'b57f01fe.jpg'], set of Ids: {'w_f672e01', 'new_whale'}
# Duplicate images: ['2a7f4c7f.jpg', '958db488.jpg'], set of Ids: {'w_ea2385d', 'new_whale'}
# Duplicate images: ['982e82e2.jpg', 'b74e0a23.jpg'], set of Ids: {'w_49308df', 'new_whale'}
# Duplicate images: ['c3fd03e4.jpg', 'defc3e26.jpg'], set of Ids: {'w_733fe81'}
# Duplicate images: ['7236c1f6.jpg', 'dfc81206.jpg'], set of Ids: {'w_41ed8e8', 'new_whale'}
# Duplicate images: ['2f778f6c.jpg', 'bb2a1714.jpg'], set of Ids: {'w_3de676c', 'new_whale'}
# Duplicate images: ['c8c79ef8.jpg', 'fc987c42.jpg'], set of Ids: {'w_29d2cec'}
# Duplicate images: ['1ed3efdf.jpg', '4f14b36d.jpg'], set of Ids: {'w_6e47e0e'}
# Duplicate images: ['590169a6.jpg', '8374dad3.jpg'], set of Ids: {'w_3a7d86d'}
# Duplicate images: ['4ac1e65c.jpg', '5a4d75b9.jpg'], set of Ids: {'w_d0932d8'}
# Duplicate images: ['ce8509c7.jpg', 'e2f55642.jpg'], set of Ids: {'w_24212f5'}
# Duplicate images: ['fc1882b1.jpg', 'fed3bc99.jpg'], set of Ids: {'w_3b0894d'}
# Duplicate images: ['5cb8a098.jpg', 'c5c3c653.jpg'], set of Ids: {'w_a687e28'}
# Duplicate images: ['6a7542ac.jpg', 'ea08df04.jpg'], set of Ids: {'w_7c7a78c'}
# Duplicate images: ['b84950d2.jpg', 'e2cc7025.jpg'], set of Ids: {'w_32a920b'}
# Duplicate images: ['626ff3eb.jpg', '802dee44.jpg'], set of Ids: {'w_f115d53', 'new_whale'}
# Duplicate images: ['4e07137d.jpg', '72b2d1b9.jpg'], set of Ids: {'w_75e6bf3'}
# Duplicate images: ['db4d5f31.jpg', 'dbcefc59.jpg'], set of Ids: {'w_23e4e61'}
# Duplicate images: ['7cf9e593.jpg', 'c7239eb8.jpg'], set of Ids: {'w_4cc3219'}
# Duplicate images: ['161aecc9.jpg', '25680592.jpg'], set of Ids: {'w_4a78bf2'}
# Duplicate images: ['5f17a866.jpg', 'a3b5f20e.jpg'], set of Ids: {'w_eb47189'}
# Duplicate images: ['633af56a.jpg', 'aab0c448.jpg'], set of Ids: {'w_20f86e1', 'new_whale'}
# Duplicate images: ['8f6e2cef.jpg', 'aa8282dc.jpg'], set of Ids: {'w_5b99089'}
# Duplicate images: ['08593f8e.jpg', '581c8a58.jpg'], set of Ids: {'w_a965f14'}
# Duplicate images: ['114903fe.jpg', 'c3d5f724.jpg'], set of Ids: {'w_511c464'}
# Duplicate images: ['699a959b.jpg', '7189208a.jpg'], set of Ids: {'w_6ef68ed'}
# Duplicate images: ['8327be2a.jpg', '9fe928f6.jpg'], set of Ids: {'w_b6efe77', 'w_741861e'}
# Duplicate images: ['0d01adda.jpg', '8a5d512d.jpg'], set of Ids: {'w_07e92ee'}
# Duplicate images: ['1509a2ee.jpg', '93c65b7a.jpg'], set of Ids: {'w_8325a79'}
# Duplicate images: ['0fb2525d.jpg', '1d2c234e.jpg'], set of Ids: {'w_0ee4d6d'}
# Duplicate images: ['d5b5f035.jpg', 'e7dff384.jpg'], set of Ids: {'w_6a3210a'}
# Duplicate images: ['42d02843.jpg', 'c70fe7e6.jpg'], set of Ids: {'w_3881300'}
# Duplicate images: ['548fa323.jpg', 'a0f170a8.jpg'], set of Ids: {'w_8c1e2e4'}
# Duplicate images: ['271cd883.jpg', '9d33b18f.jpg'], set of Ids: {'w_c8d20aa'}
# Duplicate images: ['19ccda05.jpg', '85a0fd71.jpg'], set of Ids: {'w_7759db0'}
# Duplicate images: ['2b182122.jpg', '87871fa5.jpg'], set of Ids: {'w_92be3ca'}
# Duplicate images: ['71aa9cbe.jpg', '8bf9d35a.jpg'], set of Ids: {'w_3fe1eb9'}
# Duplicate images: ['4d11635e.jpg', '79774219.jpg'], set of Ids: {'w_6163581', 'new_whale'}
# Duplicate images: ['1e3c0607.jpg', '8d2663c1.jpg'], set of Ids: {'w_5dd4772'}
# Duplicate images: ['aa0d5462.jpg', 'de10d8a0.jpg'], set of Ids: {'new_whale', 'w_c9111ac'}
# Duplicate images: ['74043d17.jpg', 'e72d982a.jpg'], set of Ids: {'w_49bbc79'}
# Duplicate images: ['0ca843f9.jpg', 'b5573551.jpg'], set of Ids: {'w_5a0d250', 'new_whale'}
# Duplicate images: ['3a085cba.jpg', '5b3c6830.jpg'], set of Ids: {'w_3f91e04'}
# Duplicate images: ['5e07c7c0.jpg', '6ce0adc1.jpg'], set of Ids: {'w_69df882'}
# Duplicate images: ['4f956a19.jpg', '5b4a682d.jpg'], set of Ids: {'w_1a70685', 'new_whale'}
# Duplicate images: ['6be35444.jpg', 'c2f5f0a6.jpg'], set of Ids: {'w_e7f03cf'}
# Duplicate images: ['3e91ad0d.jpg', 'f7b4598a.jpg'], set of Ids: {'w_8a4b8ef', 'new_whale'}
# Duplicate images: ['503b542b.jpg', '52512ce8.jpg'], set of Ids: {'w_8867074'}
# Duplicate images: ['2eb590c7.jpg', '941479c5.jpg'], set of Ids: {'w_41a79d7', 'new_whale'}
# Duplicate images: ['6105d2f4.jpg', '824d56d6.jpg'], set of Ids: {'w_c8d20aa'}
# Duplicate images: ['3013b01e.jpg', 'bc384db2.jpg'], set of Ids: {'w_9ca943b'}
# Duplicate images: ['ebcd978e.jpg', 'ee98ae53.jpg'], set of Ids: {'w_90201e3'}
# Duplicate images: ['9d31d843.jpg', 'bc08d13f.jpg'], set of Ids: {'w_dfd7ee8'}
# Duplicate images: ['5244c139.jpg', 'fdca36b9.jpg'], set of Ids: {'w_4fd48e7'}
# Duplicate images: ['a14f7c43.jpg', 'f702325b.jpg'], set of Ids: {'w_03c84ef'}
# Duplicate images: ['b8ccdcd8.jpg', 'd550e30b.jpg'], set of Ids: {'w_f4ac89a'}
# Duplicate images: ['51e74294.jpg', '7df67375.jpg'], set of Ids: {'w_b0e05b1'}
# Duplicate images: ['11322cb2.jpg', '3bcf84af.jpg'], set of Ids: {'w_6092d5c'}
# Duplicate images: ['0745ef3f.jpg', '6887e09f.jpg'], set of Ids: {'w_18a1bf2'}
# Duplicate images: ['54ed8a83.jpg', 'feb15de4.jpg'], set of Ids: {'w_8d46cef'}
# Duplicate images: ['4347d4d2.jpg', 'f9b673fd.jpg'], set of Ids: {'w_7257028'}
# Duplicate images: ['af759290.jpg', 'ef04b2bf.jpg'], set of Ids: {'w_1c2fb13'}
# Duplicate images: ['0ae14ed7.jpg', 'f087247d.jpg'], set of Ids: {'w_8103039'}
# Duplicate images: ['bb95262c.jpg', 'fd30f7e6.jpg'], set of Ids: {'w_9b401eb', 'new_whale'}
# Duplicate images: ['dd5763ff.jpg', 'fa4822c4.jpg'], set of Ids: {'w_8d9c6fc'}
# Duplicate images: ['69acdf57.jpg', '7b569203.jpg'], set of Ids: {'w_3fc3d07'}
# Duplicate images: ['71ffa6c5.jpg', 'b8e3edd2.jpg'], set of Ids: {'w_31b020c', 'new_whale'}
# Duplicate images: ['3b82237b.jpg', '5411a5c6.jpg'], set of Ids: {'w_9771603'}
# Duplicate images: ['692a3e82.jpg', 'a3fd6a7f.jpg'], set of Ids: {'w_64830fa'}
# Duplicate images: ['8504db72.jpg', 'd1b3f470.jpg'], set of Ids: {'w_d89b29e', 'new_whale'}
# Duplicate images: ['7a3b61de.jpg', 'b0d26c4d.jpg'], set of Ids: {'w_01687a8'}
# Duplicate images: ['42cf9ddf.jpg', 'd5c21ca0.jpg'], set of Ids: {'w_d708c5a'}
# Duplicate images: ['188446bc.jpg', 'dc7b1165.jpg'], set of Ids: {'w_f19faeb'}
# Duplicate images: ['342ea7cf.jpg', '8bd96828.jpg'], set of Ids: {'w_3feb2df'}
# Duplicate images: ['72469a66.jpg', 'cf46e113.jpg'], set of Ids: {'w_c0d494d', 'new_whale'}
# Duplicate images: ['81c129dd.jpg', 'b69b0ded.jpg'], set of Ids: {'w_471ae98', 'new_whale'}
# Duplicate images: ['80d24d0c.jpg', '84796ad8.jpg'], set of Ids: {'w_13f8407'}
# Duplicate images: ['64d74ec8.jpg', 'a3132d22.jpg'], set of Ids: {'w_c9e1cdc', 'new_whale'}
# Duplicate images: ['151f1e39.jpg', 'b9fe7c00.jpg'], set of Ids: {'w_2f81b85', 'new_whale'}
# Duplicate images: ['0c6170eb.jpg', '63c18173.jpg'], set of Ids: {'w_a646643'}
# Duplicate images: ['6d94c21a.jpg', '6fca3646.jpg'], set of Ids: {'w_637f363'}
# Duplicate images: ['151b97b3.jpg', '2da044f5.jpg'], set of Ids: {'w_fca13e2', 'new_whale'}
# Duplicate images: ['798e0c06.jpg', '9ac5ba2c.jpg'], set of Ids: {'w_d88328d'}
# Duplicate images: ['c87be503.jpg', 'f3402127.jpg'], set of Ids: {'w_89e159a'}
# Duplicate images: ['9d59ff47.jpg', 'c2aa02a4.jpg'], set of Ids: {'w_3694c7d'}
# Duplicate images: ['1779d2fe.jpg', 'bbfb000c.jpg'], set of Ids: {'w_e30e97f', 'new_whale'}
# Duplicate images: ['057644d1.jpg', 'fb5f5b93.jpg'], set of Ids: {'w_7c6ad05'}
# Duplicate images: ['2c3e707c.jpg', 'fe3329b4.jpg'], set of Ids: {'w_a837660', 'new_whale'}
# Duplicate images: ['3ae20220.jpg', 'b8951041.jpg'], set of Ids: {'w_93e1b76', 'new_whale'}
# Duplicate images: ['965f25eb.jpg', 'c5c8305d.jpg'], set of Ids: {'w_80b1c48'}
# Duplicate images: ['0025e8c2.jpg', 'f4c81765.jpg'], set of Ids: {'w_8b1ca89'}
# Duplicate images: ['72ef4e0f.jpg', '78c06fcd.jpg'], set of Ids: {'w_1a70685'}
# Duplicate images: ['95d95348.jpg', 'dd25e679.jpg'], set of Ids: {'w_ca8bfb4'}
# Duplicate images: ['06b62519.jpg', '883796e8.jpg'], set of Ids: {'w_5dc1c2d'}
# Duplicate images: ['2f4347f4.jpg', '66cb1bde.jpg'], set of Ids: {'w_56bbc91'}
# Duplicate images: ['41981a88.jpg', '74934a2c.jpg'], set of Ids: {'w_6361632', 'new_whale'}
# Duplicate images: ['30ca0299.jpg', '75cd5008.jpg'], set of Ids: {'w_f5771d1', 'w_1000f90'}
# Duplicate images: ['99caa8ec.jpg', 'ba95dda5.jpg'], set of Ids: {'w_2855124'}
# Duplicate images: ['b1d3d395.jpg', 'cb7f7d57.jpg'], set of Ids: {'w_1e5a146', 'new_whale'}
# Duplicate images: ['129c160e.jpg', '67b30544.jpg'], set of Ids: {'w_d9aab0a'}
# Duplicate images: ['18b1f6e3.jpg', 'a39275ee.jpg'], set of Ids: {'w_09f825c'}
# Duplicate images: ['0d8a9dda.jpg', '4cb79ce5.jpg'], set of Ids: {'w_8de6989'}
# Duplicate images: ['857d2743.jpg', '8bcac806.jpg'], set of Ids: {'w_b6410bc', 'new_whale'}
# Duplicate images: ['8c826fd3.jpg', 'ba846ad3.jpg'], set of Ids: {'w_6547e12'}
# Duplicate images: ['74e83810.jpg', 'aaa2cdd3.jpg'], set of Ids: {'w_fe2742d', 'new_whale'}
# Duplicate images: ['5d5d16d7.jpg', '877aba70.jpg'], set of Ids: {'w_f714476'}
# Duplicate images: ['8033d7bc.jpg', 'a12f4f8a.jpg'], set of Ids: {'w_aa70bc3'}
# Duplicate images: ['37b38907.jpg', '6e856d8b.jpg'], set of Ids: {'w_2fe43c7', 'new_whale'}
# Duplicate images: ['c571f41e.jpg', 'f0255523.jpg'], set of Ids: {'w_24fda6e'}
# Duplicate images: ['467e4991.jpg', 'c9c3d82e.jpg'], set of Ids: {'w_7554f44'}
# Duplicate images: ['a1751aaa.jpg', 'a8c1fb30.jpg'], set of Ids: {'w_dd60c18', 'new_whale'}
# Duplicate images: ['c7bf6ae9.jpg', 'e69e6d59.jpg'], set of Ids: {'w_2fe43c7', 'new_whale'}
# Duplicate images: ['1d6cf53b.jpg', 'aa897d21.jpg'], set of Ids: {'w_511c464', 'new_whale'}
# Duplicate images: ['78535648.jpg', '8ce7ec5b.jpg'], set of Ids: {'w_bbf58a9'}
# Duplicate images: ['28624189.jpg', 'b5f46cf1.jpg'], set of Ids: {'w_bb2d34d', 'new_whale'}
# Duplicate images: ['2762699d.jpg', '6eb9cd51.jpg'], set of Ids: {'w_16d1b32'}
# Duplicate images: ['73ad084c.jpg', 'cda04cc4.jpg'], set of Ids: {'w_8397970'}
# Duplicate images: ['58e61a8a.jpg', '734430c9.jpg'], set of Ids: {'w_e7f8e67'}
# Duplicate images: ['ec6e335f.jpg', 'f2c504bc.jpg'], set of Ids: {'w_60759c2'}
# Duplicate images: ['9cadcad7.jpg', 'df2df035.jpg'], set of Ids: {'w_ee17a08'}
# Duplicate images: ['6954aabe.jpg', 'cf2da6b3.jpg'], set of Ids: {'w_3d66298'}
# Duplicate images: ['3326845f.jpg', 'a74c681c.jpg'], set of Ids: {'w_8596faf'}
# Duplicate images: ['0101d22b.jpg', '7f19b200.jpg'], set of Ids: {'w_af67683'}
# Duplicate images: ['13d83e1f.jpg', '5d1c88c7.jpg'], set of Ids: {'w_577e627'}
# Duplicate images: ['8d9b4a76.jpg', '9f3a9096.jpg'], set of Ids: {'w_32a920b', 'new_whale'}
# Duplicate images: ['33214781.jpg', '44722f31.jpg'], set of Ids: {'w_62c6a8c', 'new_whale'}
# Duplicate images: ['682eac9e.jpg', 'c84e11ea.jpg'], set of Ids: {'w_ab1c859'}
# Duplicate images: ['9e241fe2.jpg', 'f4419241.jpg'], set of Ids: {'w_900f9eb'}
# Duplicate images: ['522b1d12.jpg', '902324b0.jpg'], set of Ids: {'w_1f09cdd', 'new_whale'}
# Duplicate images: ['62c8b6cc.jpg', 'c443b508.jpg'], set of Ids: {'w_6092d5c'}
# Duplicate images: ['0e4e6449.jpg', 'c80d3657.jpg'], set of Ids: {'w_63d10a1', 'new_whale'}
# Duplicate images: ['29e1033b.jpg', 'ce30b151.jpg'], set of Ids: {'w_7311fe4'}
# Duplicate images: ['30d6aaa9.jpg', 'b3255607.jpg'], set of Ids: {'w_ee9c4d7', 'new_whale'}
# Duplicate images: ['8224f7c6.jpg', 'a35d3e18.jpg'], set of Ids: {'w_dc7c5a0'}
# Duplicate images: ['714c00fa.jpg', '8c4a3240.jpg'], set of Ids: {'w_2e4fecc'}
# Duplicate images: ['04a91387.jpg', '25e4186d.jpg'], set of Ids: {'w_eec1133'}
# Duplicate images: ['1d95c233.jpg', 'd4ba416d.jpg'], set of Ids: {'w_8c957e0'}
# Duplicate images: ['c5fd7c1d.jpg', 'd3511660.jpg'], set of Ids: {'w_3bc8a47'}
# Duplicate images: ['8d261dbf.jpg', 'e7e9055a.jpg'], set of Ids: {'w_bf77b13'}
# Duplicate images: ['8c73f846.jpg', 'c75f810f.jpg'], set of Ids: {'w_61e1076'}
# Duplicate images: ['096f4caa.jpg', '6f660c6d.jpg'], set of Ids: {'w_2b443f8'}
# Duplicate images: ['074f068b.jpg', '6fb10498.jpg'], set of Ids: {'w_d96a0cd'}
# Duplicate images: ['2c70f875.jpg', '70500cf8.jpg'], set of Ids: {'w_b34793e'}
# Duplicate images: ['09f70419.jpg', 'b9b5fd2c.jpg'], set of Ids: {'w_3278f8c'}
# Duplicate images: ['632aa354.jpg', '87c28a57.jpg'], set of Ids: {'w_ffda8b2'}
# Duplicate images: ['7335e02f.jpg', 'f0a51fbf.jpg'], set of Ids: {'w_c4c8491'}
# Duplicate images: ['cba81909.jpg', 'cf0f99d2.jpg'], set of Ids: {'w_d9055d1', 'new_whale'}
# Duplicate images: ['0f550bb8.jpg', 'c081d117.jpg'], set of Ids: {'w_652e069', 'new_whale'}
# Duplicate images: ['5cb9577a.jpg', 'a03fbc87.jpg'], set of Ids: {'w_9c449e2'}
# Duplicate images: ['140bf7f2.jpg', 'c4a027dd.jpg'], set of Ids: {'w_d2be6cc'}
# Duplicate images: ['4bcd1de9.jpg', 'cc988a57.jpg'], set of Ids: {'w_a358522'}
# Duplicate images: ['34f70512.jpg', '7cbb4d0e.jpg'], set of Ids: {'w_932c8cd'}
# Duplicate images: ['0323fcfc.jpg', 'cf5c4d4a.jpg'], set of Ids: {'w_cd22b23'}
# Duplicate images: ['1d35c098.jpg', '6464d236.jpg'], set of Ids: {'w_5a2075e'}
# Duplicate images: ['491b2597.jpg', '79fa89c7.jpg'], set of Ids: {'w_6d90f45'}
# Duplicate images: ['4d9308ae.jpg', '81547d94.jpg'], set of Ids: {'w_ba302c8', 'new_whale'}
# Duplicate images: ['a176d744.jpg', 'e34c10d1.jpg'], set of Ids: {'w_4fd48e7'}
# Duplicate images: ['43b43ee2.jpg', 'd804659e.jpg'], set of Ids: {'w_e964ae8', 'new_whale'}
# Duplicate images: ['b1485028.jpg', 'feb1ecd3.jpg'], set of Ids: {'w_b9c9129', 'new_whale'}
# Duplicate images: ['94b86b9f.jpg', 'f54a1b5f.jpg'], set of Ids: {'w_d3ef4b2'}
# Duplicate images: ['a1871308.jpg', 'c25c321d.jpg'], set of Ids: {'w_3e02970'}
# Duplicate images: ['6358dcad.jpg', 'e17055c6.jpg'], set of Ids: {'w_ae07541'}
# Duplicate images: ['358cf2ae.jpg', 'e9c8b1c7.jpg'], set of Ids: {'w_bf69a19'}
# Duplicate images: ['75412872.jpg', 'bbf6a75b.jpg'], set of Ids: {'w_b4732ef', 'new_whale'}
# Duplicate images: ['45c835b5.jpg', 'f28bf64d.jpg'], set of Ids: {'w_1da7080'}
# Duplicate images: ['1c4f6efe.jpg', 'e4dc6ec8.jpg'], set of Ids: {'w_fd1cb9d'}
# Duplicate images: ['117bb995.jpg', 'c397e521.jpg'], set of Ids: {'w_c26666e'}
# Duplicate images: ['6ad9c4b8.jpg', '8a26e9f8.jpg'], set of Ids: {'w_44cccf6', 'new_whale'}
# Duplicate images: ['5498c4d1.jpg', '77614080.jpg'], set of Ids: {'w_0d60fdd'}
# Duplicate images: ['568dec18.jpg', 'd466dea4.jpg'], set of Ids: {'w_1c30ba6'}
# Duplicate images: ['66bc6504.jpg', 'f0e5ca20.jpg'], set of Ids: {'w_4be373e'}
# Duplicate images: ['74f4b95c.jpg', 'a654239e.jpg'], set of Ids: {'w_4fcfa4d'}
# Duplicate images: ['696c2cfe.jpg', '7fe98b33.jpg'], set of Ids: {'w_e964ae8'}
# Duplicate images: ['c0dc322d.jpg', 'f233ed87.jpg'], set of Ids: {'w_a913945'}
# Duplicate images: ['5a54ab49.jpg', 'ac0beccb.jpg'], set of Ids: {'w_fd1cb9d'}
# Duplicate images: ['8d715656.jpg', 'ce3e0bc9.jpg'], set of Ids: {'w_38efce7'}
# Duplicate images: ['93240258.jpg', 'bf64e8f6.jpg'], set of Ids: {'w_53951e6'}
# Duplicate images: ['598f3afd.jpg', '64c37ec4.jpg'], set of Ids: {'w_3bb210a'}
# Duplicate images: ['34f5202b.jpg', '680ab32d.jpg'], set of Ids: {'w_e082823'}
# Duplicate images: ['2f62df9b.jpg', '81af185a.jpg'], set of Ids: {'w_5abb7d5'}
# Duplicate images: ['8904e37f.jpg', '9314677e.jpg'], set of Ids: {'w_f0f0dbb', 'new_whale'}
# Duplicate images: ['857a837c.jpg', 'c789cc0d.jpg'], set of Ids: {'w_51cdd4b'}
# Duplicate images: ['b310caa2.jpg', 'bf462c1e.jpg'], set of Ids: {'w_3fa2cb1'}
# Duplicate images: ['b5b0a8ad.jpg', 'de52048e.jpg'], set of Ids: {'w_0988bbb'}
# Duplicate images: ['a842b280.jpg', 'ff5a5ed4.jpg'], set of Ids: {'w_f3bd33a'}
# Duplicate images: ['842686a1.jpg', 'd5d3808d.jpg'], set of Ids: {'w_2c55303', 'new_whale'}
# Duplicate images: ['506e4452.jpg', '70ad0502.jpg'], set of Ids: {'w_186bcab'}
# Duplicate images: ['1290161b.jpg', 'f3083f28.jpg'], set of Ids: {'w_33c3ce1'}
# Duplicate images: ['34aaad19.jpg', '3befe86f.jpg'], set of Ids: {'w_0e4f53c'}
# Duplicate images: ['46d882ea.jpg', '71e4971a.jpg'], set of Ids: {'w_65428d9'}
# Duplicate images: ['651556e0.jpg', 'f01dc26d.jpg'], set of Ids: {'w_524f51e'}
# Duplicate images: ['040d8913.jpg', 'ee5c7600.jpg'], set of Ids: {'w_44f66a7'}
# Duplicate images: ['7498e803.jpg', 'b855bace.jpg'], set of Ids: {'w_2a9727c', 'new_whale'}
# Duplicate images: ['10ca2e75.jpg', '2f9e7a12.jpg'], set of Ids: {'w_f03ca16'}
# Duplicate images: ['29910dbd.jpg', 'f14d863f.jpg'], set of Ids: {'w_a9dd349'}
# Duplicate images: ['2f899d4d.jpg', '46b7dba5.jpg'], set of Ids: {'w_dcb1f2a', 'new_whale'}
# Duplicate images: ['6f0d0f16.jpg', 'c7e0f43c.jpg'], set of Ids: {'w_430766d'}
# Duplicate images: ['73d6148c.jpg', 'e1ac27f9.jpg'], set of Ids: {'w_964c1b3'}
# Duplicate images: ['028d2ff2.jpg', '1a9f2a01.jpg'], set of Ids: {'w_5297ab3'}
# Duplicate images: ['b846cc62.jpg', 'fc7bbbe2.jpg'], set of Ids: {'w_a3dbc8f'}
# Duplicate images: ['742bb8ee.jpg', '9e8a787e.jpg'], set of Ids: {'w_3026ce2'}
# Duplicate images: ['32997992.jpg', '76b23d2c.jpg'], set of Ids: {'w_b6886e5'}
# Duplicate images: ['5596e225.jpg', '84e9fc47.jpg'], set of Ids: {'w_886257d'}
# Duplicate images: ['5f426af5.jpg', '9d4ce17b.jpg'], set of Ids: {'w_817f022'}
# Duplicate images: ['1e1fe67e.jpg', '4c0f0c45.jpg'], set of Ids: {'w_ace8c54'}
# Duplicate images: ['513b0516.jpg', 'a325fa59.jpg'], set of Ids: {'w_febafc1'}
# Duplicate images: ['8d786ab8.jpg', 'e60d8296.jpg'], set of Ids: {'w_05b2ddd'}
# Duplicate images: ['1f929002.jpg', 'a02f5fbf.jpg'], set of Ids: {'w_76d5723'}
# Duplicate images: ['549c47d5.jpg', '8aa8e20f.jpg'], set of Ids: {'new_whale', 'w_8a438a4'}
# Duplicate images: ['119bba45.jpg', '42c5f272.jpg'], set of Ids: {'w_19dc50f'}
# Duplicate images: ['2b3fd959.jpg', '7b12411a.jpg'], set of Ids: {'w_2739d94', 'new_whale'}
# Duplicate images: ['472aefb7.jpg', '8d8852ce.jpg'], set of Ids: {'w_7e8b270'}
# Duplicate images: ['8ba28ad0.jpg', 'a187c363.jpg'], set of Ids: {'w_3c4062e'}
# Duplicate images: ['2353565f.jpg', 'd55271ee.jpg'], set of Ids: {'w_817f022'}
# Duplicate images: ['9c46a373.jpg', 'c6f52c45.jpg'], set of Ids: {'w_09e0cbf', 'new_whale'}
# Duplicate images: ['76021b49.jpg', 'd3b2bfbd.jpg'], set of Ids: {'w_c11932e'}
# Duplicate images: ['50ada087.jpg', '9dc8cf7f.jpg'], set of Ids: {'w_d9055d1'}
# Duplicate images: ['4ca241b1.jpg', '5f8d9492.jpg'], set of Ids: {'w_ef89416', 'new_whale'}
# Duplicate images: ['806cf583.jpg', 'c5da34e7.jpg'], set of Ids: {'w_0bc1db0'}
# Duplicate images: ['3ce7d968.jpg', 'b4a17d44.jpg'], set of Ids: {'w_12cdfbd'}
# Duplicate images: ['ba4a4729.jpg', 'f30cb844.jpg'], set of Ids: {'w_64f3545'}
# Duplicate images: ['67758056.jpg', '9cd2fa20.jpg'], set of Ids: {'w_d8e752e', 'new_whale'}
# Duplicate images: ['263246e0.jpg', '7db2f364.jpg'], set of Ids: {'w_f5b8faf'}
# Duplicate images: ['4390f29c.jpg', '67f88e3e.jpg'], set of Ids: {'w_778ee6e'}
# Duplicate images: ['bd91e244.jpg', 'c941efe9.jpg'], set of Ids: {'w_22bcbd6', 'new_whale'}
# Duplicate images: ['7e9a738f.jpg', 'd6b5f3bc.jpg'], set of Ids: {'w_3349c9d'}
# Duplicate images: ['776b0b63.jpg', '8d7606bf.jpg'], set of Ids: {'w_89e159a'}
# Duplicate images: ['1efe5ef7.jpg', 'f5287173.jpg'], set of Ids: {'w_11f6df1', 'new_whale'}
# Duplicate images: ['6833e195.jpg', 'c8ed816a.jpg'], set of Ids: {'w_9c3db0a'}
# Duplicate images: ['5d720476.jpg', '92c07ce1.jpg'], set of Ids: {'w_e7a238b'}
# Duplicate images: ['1c0a7333.jpg', '71d1dac1.jpg'], set of Ids: {'w_91a96d8', 'new_whale'}
# Duplicate images: ['19546e12.jpg', 'c6d31eca.jpg'], set of Ids: {'w_7885601'}
# Duplicate images: ['0fc63e94.jpg', '8f1dd850.jpg'], set of Ids: {'w_9771603'}
# Duplicate images: ['30b0c9f7.jpg', '349954e5.jpg'], set of Ids: {'w_c30959a'}
# Duplicate images: ['f3e6be96.jpg', 'f5d4f61d.jpg'], set of Ids: {'w_0013924'}
# Duplicate images: ['5fe11dcd.jpg', '717bb12f.jpg'], set of Ids: {'w_656afeb'}
# Duplicate images: ['c97b3d74.jpg', 'cc95eb5d.jpg'], set of Ids: {'w_3411b9f'}
# Duplicate images: ['0fc584fc.jpg', '576eb384.jpg'], set of Ids: {'w_a14ccaa'}
# Duplicate images: ['66e24bcb.jpg', '81c7542f.jpg'], set of Ids: {'w_daeb296'}
# Duplicate images: ['3f7a3e4c.jpg', '8234edd0.jpg'], set of Ids: {'w_a67a1bc', 'w_e8a9fb8'}
# Duplicate images: ['4398e933.jpg', 'fa2b1d93.jpg'], set of Ids: {'w_c666071', 'new_whale'}
# Duplicate images: ['71ca897f.jpg', 'cd0b0b63.jpg'], set of Ids: {'w_fb72090'}
# Duplicate images: ['973d410c.jpg', 'e0dda879.jpg'], set of Ids: {'w_d96a0cd', 'new_whale'}
# Duplicate images: ['1c5e11ba.jpg', 'fabfd54e.jpg'], set of Ids: {'w_4ec48a9'}
# Duplicate images: ['03c696a6.jpg', 'ff24f0ea.jpg'], set of Ids: {'w_3d0bc7a'}
# Duplicate images: ['78aa3bf4.jpg', 'a9537d17.jpg'], set of Ids: {'w_17a3581'}
# Duplicate images: ['05293254.jpg', '4e516705.jpg'], set of Ids: {'w_d6e437d'}
# Duplicate images: ['8ae8c9f3.jpg', 'eb18dd56.jpg'], set of Ids: {'w_217e78a'}
# Duplicate images: ['3bf857ac.jpg', '52a0de28.jpg'], set of Ids: {'w_c6be61e', 'new_whale'}
# Duplicate images: ['0df89aea.jpg', '4ebcbc3f.jpg'], set of Ids: {'w_28ce17c'}
# Duplicate images: ['0b23f8c1.jpg', '86bbdb3f.jpg'], set of Ids: {'w_32037e2'}
# Duplicate images: ['3df0eea0.jpg', '8b0e1a97.jpg'], set of Ids: {'w_5f82501'}
# Duplicate images: ['6b7e611f.jpg', 'ab23c714.jpg'], set of Ids: {'w_44cccf6'}
# Duplicate images: ['427cb01b.jpg', '82f4228e.jpg'], set of Ids: {'w_e0818df'}
# Duplicate images: ['216bf1fd.jpg', '599ea85b.jpg'], set of Ids: {'w_3694c7d'}
# Duplicate images: ['4fa87955.jpg', '7dff8da6.jpg'], set of Ids: {'w_1969a9d'}
# Duplicate images: ['832f79d2.jpg', 'b46827f4.jpg'], set of Ids: {'w_f4d89bb'}
# Duplicate images: ['9bb6f188.jpg', 'e6ffa80c.jpg'], set of Ids: {'w_778ee6e', 'new_whale'}
# Duplicate images: ['701544db.jpg', '848bbffe.jpg'], set of Ids: {'w_b05c57f'}
# Duplicate images: ['b81d5270.jpg', 'fff04277.jpg'], set of Ids: {'w_2dcbf82'}
# Duplicate images: ['05f4fd87.jpg', 'bcb70ecd.jpg'], set of Ids: {'w_71e6583', 'new_whale'}
# Duplicate images: ['0eb0a241.jpg', 'de5e38fe.jpg'], set of Ids: {'w_38e4aae'}
# Duplicate images: ['85040559.jpg', 'e602ccd0.jpg'], set of Ids: {'w_c1b3568', 'new_whale'}
# Duplicate images: ['eebe77e5.jpg', 'fe4ce0c3.jpg'], set of Ids: {'w_5dc538d'}
# Duplicate images: ['063e62a9.jpg', 'e37e2e2f.jpg'], set of Ids: {'new_whale', 'w_845f7ca'}
# Duplicate images: ['76b68c71.jpg', '77a84cd0.jpg'], set of Ids: {'w_389c788'}
# Duplicate images: ['416bb0ad.jpg', 'd908f6f5.jpg'], set of Ids: {'w_7e8b270'}
# Duplicate images: ['49f289ca.jpg', '7f995302.jpg'], set of Ids: {'w_d2e1f2a'}
# Duplicate images: ['b27a43e7.jpg', 'c1a9b238.jpg'], set of Ids: {'w_0a91f24'}
# Duplicate images: ['81003525.jpg', 'b472b5a8.jpg'], set of Ids: {'w_c0cfd5b'}
# Duplicate images: ['4235f9c3.jpg', 'b31889e2.jpg'], set of Ids: {'w_eb0a6ed'}
# Duplicate images: ['35451820.jpg', '454f9b95.jpg'], set of Ids: {'w_0265cb6'}
# Duplicate images: ['c64911d3.jpg', 'fd9c0764.jpg'], set of Ids: {'w_98d4838'}
# Duplicate images: ['b1b3fc53.jpg', 'b5aeb403.jpg'], set of Ids: {'w_9e1e818'}
# Duplicate images: ['27aecf3d.jpg', 'd11be164.jpg'], set of Ids: {'w_3f90907'}
# Duplicate images: ['6e26b2fd.jpg', 'c7102d1c.jpg'], set of Ids: {'w_2f6e76c', 'new_whale'}
# Duplicate images: ['a2aff525.jpg', 'e55ed2ec.jpg'], set of Ids: {'w_b688397'}
# Duplicate images: ['29406608.jpg', '9bb38476.jpg'], set of Ids: {'w_0988bbb'}
# Duplicate images: ['a7fe5fa0.jpg', 'b19dd70e.jpg'], set of Ids: {'w_61d516e'}
# Duplicate images: ['42a288b9.jpg', '720e65ad.jpg'], set of Ids: {'w_0a71e87'}
# Duplicate images: ['94d5c3ec.jpg', 'b23234f2.jpg'], set of Ids: {'w_a8da4a3', 'new_whale'}
# Duplicate images: ['1fb990d1.jpg', '84905fba.jpg'], set of Ids: {'w_f19faeb'}
# Duplicate images: ['2f2e80a5.jpg', '8c81d937.jpg'], set of Ids: {'w_5810973'}
# Duplicate images: ['471cc7c1.jpg', '91290e16.jpg'], set of Ids: {'w_fe49bc4'}
# Duplicate images: ['2383cecf.jpg', 'f44df450.jpg'], set of Ids: {'w_057c418'}
# Duplicate images: ['1493f41c.jpg', 'e80b4c69.jpg'], set of Ids: {'w_451f507'}
# Duplicate images: ['1cc06259.jpg', '2487e817.jpg'], set of Ids: {'w_9146eae'}
# Duplicate images: ['4ff2c7cb.jpg', 'dd5bcda3.jpg'], set of Ids: {'w_813c5be'}
# Duplicate images: ['bcfc650a.jpg', 'f2088658.jpg'], set of Ids: {'w_5d96ba4'}
# Duplicate images: ['2c1df05d.jpg', '50e6f606.jpg'], set of Ids: {'w_41ed8e8', 'new_whale'}
# Duplicate images: ['5d6e4cca.jpg', 'e69adebc.jpg'], set of Ids: {'w_11adaae'}
# Duplicate images: ['98746ad3.jpg', 'fe450c91.jpg'], set of Ids: {'w_c2c4f43'}
# Duplicate images: ['cfb47c92.jpg', 'd0eb3628.jpg'], set of Ids: {'w_0c6dbbe'}
# Duplicate images: ['34a1c0e0.jpg', 'fba04b43.jpg'], set of Ids: {'w_7324cf5'}
# Duplicate images: ['6e29caa7.jpg', 'f7bbc4ee.jpg'], set of Ids: {'w_7133c9d', 'new_whale'}
# Duplicate images: ['aa56de1b.jpg', 'e1be22bd.jpg'], set of Ids: {'w_83df8d5', 'new_whale'}
# Duplicate images: ['56b7d8a9.jpg', 'dab51a44.jpg'], set of Ids: {'w_1a5e7a2'}
# Duplicate images: ['3aff0139.jpg', '6a932a92.jpg'], set of Ids: {'w_cfe35d4'}
# Duplicate images: ['10e456b3.jpg', '8973f78a.jpg'], set of Ids: {'w_cc009e5'}
# Duplicate images: ['71eaceca.jpg', 'd74b6ee9.jpg'], set of Ids: {'w_20e863f'}
# Duplicate images: ['2f87bbcf.jpg', 'f708d105.jpg'], set of Ids: {'w_01f211f'}
# Duplicate images: ['5558710f.jpg', '83ebd3ab.jpg'], set of Ids: {'w_6ee7470', 'new_whale'}
# Duplicate images: ['13d23cf5.jpg', 'e15ff5de.jpg'], set of Ids: {'w_c622a3f'}
# Duplicate images: ['af943b37.jpg', 'b2ffcaca.jpg'], set of Ids: {'w_9ceb05d', 'new_whale'}
# Duplicate images: ['64566f1b.jpg', 'a9767dd2.jpg'], set of Ids: {'w_95874a5', 'new_whale'}
# Duplicate images: ['0acce63b.jpg', 'b02e5613.jpg'], set of Ids: {'w_7554f44'}
# Duplicate images: ['80b855fe.jpg', 'b301cded.jpg'], set of Ids: {'w_93b64e9'}
# Duplicate images: ['76611f14.jpg', 'f2305c60.jpg'], set of Ids: {'w_44cccf6', 'new_whale'}
# Duplicate images: ['0bfb2b72.jpg', 'eff82e34.jpg'], set of Ids: {'w_19eb1b8', 'new_whale'}
# Duplicate images: ['487f8abe.jpg', 'bdcb59f8.jpg'], set of Ids: {'w_e61dd6d', 'new_whale'}
# Duplicate images: ['986ac34b.jpg', 'e9bb798d.jpg'], set of Ids: {'w_b34793e'}
# Duplicate images: ['e7318d2d.jpg', 'e8cf10ce.jpg'], set of Ids: {'w_8717ef3', 'new_whale'}
# Duplicate images: ['944a8017.jpg', 'a537e2bc.jpg'], set of Ids: {'w_b0e6fbe'}
# Duplicate images: ['653054f4.jpg', 'a23f85b0.jpg'], set of Ids: {'w_d94db94'}
# Duplicate images: ['8c4e9a56.jpg', 'f2fe6436.jpg'], set of Ids: {'w_d94c323'}
# Duplicate images: ['454737d4.jpg', 'deba1b7a.jpg'], set of Ids: {'w_f60c7e8'}
# Duplicate images: ['8fcd2b14.jpg', 'f7dd6b74.jpg'], set of Ids: {'w_33b9360'}
# Duplicate images: ['59ecd346.jpg', 'a5a404bf.jpg'], set of Ids: {'w_2a04ceb'}
# Duplicate images: ['7803fa86.jpg', 'd66b04e7.jpg'], set of Ids: {'w_5f82501'}
# Duplicate images: ['31d37c35.jpg', '7abb38c7.jpg'], set of Ids: {'w_59349ea'}
# Duplicate images: ['55676b68.jpg', '762b338b.jpg'], set of Ids: {'w_e03755a'}
# Duplicate images: ['02c8235c.jpg', 'dcc5b795.jpg'], set of Ids: {'w_e59a1f0', 'new_whale'}
# Duplicate images: ['ccf8ae42.jpg', 'd0a5bfbb.jpg'], set of Ids: {'w_8f593d4'}
# Duplicate images: ['075a3b48.jpg', '3551fc12.jpg'], set of Ids: {'w_d6a6360'}
# Duplicate images: ['4e7e02b5.jpg', '7cd49c75.jpg'], set of Ids: {'w_0ac6a0a'}
# Duplicate images: ['3a8a29d3.jpg', '7165f410.jpg'], set of Ids: {'w_598b8ab', 'new_whale'}
# Duplicate images: ['348cfa0a.jpg', 'a34a380e.jpg'], set of Ids: {'w_e3f51ec'}
# Duplicate images: ['451c8b8f.jpg', 'e940bee9.jpg'], set of Ids: {'w_02bb4cf', 'new_whale'}
# Duplicate images: ['2e8111df.jpg', '57fe5fbd.jpg'], set of Ids: {'w_3745f59', 'new_whale'}
# Duplicate images: ['39fd6394.jpg', '9bedb6a4.jpg'], set of Ids: {'w_f1b565a'}
# Duplicate images: ['b7e056f2.jpg', 'bf5dfd9a.jpg'], set of Ids: {'w_2d99a0c'}
# Duplicate images: ['55d2bfe3.jpg', '7454e74e.jpg'], set of Ids: {'w_f438375'}
# Duplicate images: ['069d05ca.jpg', 'e4cfc870.jpg'], set of Ids: {'w_8f2fb79'}
# Duplicate images: ['23c6cdab.jpg', 'b1587616.jpg'], set of Ids: {'w_43b50e5'}
# Duplicate images: ['8642f75d.jpg', 'a0df3679.jpg'], set of Ids: {'w_1ecfe96'}
# Duplicate images: ['0e5ce2da.jpg', 'c3791ea1.jpg'], set of Ids: {'w_b721e96'}
# Duplicate images: ['30fd58e5.jpg', '36165858.jpg'], set of Ids: {'w_5c6215c'}
# Duplicate images: ['81b398f6.jpg', 'c8846609.jpg'], set of Ids: {'w_e4616da'}
# Duplicate images: ['618b08f7.jpg', 'bf316fae.jpg'], set of Ids: {'w_1aa512b'}
# Duplicate images: ['5aa15488.jpg', 'ea9a1894.jpg'], set of Ids: {'w_1a5e7a2'}
# Duplicate images: ['60305a08.jpg', 'f5b6713d.jpg'], set of Ids: {'w_242a05d'}
# Duplicate images: ['070e6c95.jpg', 'e5bb5af3.jpg'], set of Ids: {'w_15d7ecf'}
# Duplicate images: ['9fa7003e.jpg', 'fefe9bdc.jpg'], set of Ids: {'w_d9aab0a'}
# Duplicate images: ['2c4b238b.jpg', 'ac584f66.jpg'], set of Ids: {'w_e3c119c'}
# Duplicate images: ['24f6e6c4.jpg', '6f4a3b50.jpg'], set of Ids: {'w_b678944'}
# Duplicate images: ['2856c5e0.jpg', 'a944e7b7.jpg'], set of Ids: {'w_64befc3'}
# Duplicate images: ['5f21490f.jpg', 'cab6c11b.jpg'], set of Ids: {'w_68fb716'}
# Duplicate images: ['8afd06fb.jpg', 'd006097c.jpg'], set of Ids: {'w_2db01d5'}
# Duplicate images: ['685d3868.jpg', 'cf1c113e.jpg'], set of Ids: {'w_7459706'}
# Duplicate images: ['3ae7b2e7.jpg', 'd9385858.jpg'], set of Ids: {'w_c9e1cdc'}
# Duplicate images: ['0444f67e.jpg', 'a575a5d8.jpg'], set of Ids: {'w_c926fc3'}
# Duplicate images: ['32880412.jpg', 'b0b78bf6.jpg'], set of Ids: {'w_dfbfe10', 'new_whale'}
# Duplicate images: ['0c88a7aa.jpg', '6699001e.jpg'], set of Ids: {'w_d36f58c', 'new_whale'}
# Duplicate images: ['11c6a61b.jpg', '5fc342ad.jpg'], set of Ids: {'w_b6689cc'}
# Duplicate images: ['467f7e29.jpg', 'cd44dc39.jpg'], set of Ids: {'w_b6ae946'}
# Duplicate images: ['6f591a74.jpg', 'cdd2705b.jpg'], set of Ids: {'w_1a229eb'}
# Duplicate images: ['b6018681.jpg', 'c8d19b0c.jpg'], set of Ids: {'w_9378098'}
# Duplicate images: ['bb8aeb09.jpg', 'cb6270bd.jpg'], set of Ids: {'w_1efd2a9'}
# Duplicate images: ['33ec74f3.jpg', 'b45cb8ed.jpg'], set of Ids: {'w_f8e6546', 'new_whale'}
# Duplicate images: ['527ff29a.jpg', 'fb7b0e02.jpg'], set of Ids: {'w_c74ab24', 'new_whale'}
# Duplicate images: ['3fb0d64d.jpg', 'c7b6ded2.jpg'], set of Ids: {'w_c30959a'}
# Duplicate images: ['667a6ea6.jpg', 'ef3578e6.jpg'], set of Ids: {'w_3b0894d'}
# Duplicate images: ['e5dfd9ab.jpg', 'e9b3dfdf.jpg'], set of Ids: {'w_dcf2001'}
# Duplicate images: ['220d0887.jpg', '54ea1e8d.jpg'], set of Ids: {'w_1854334'}
# Duplicate images: ['56893b19.jpg', 'baf56258.jpg'], set of Ids: {'w_e7f8e67'}
# Duplicate images: ['2b2eb6e1.jpg', '60b8927d.jpg'], set of Ids: {'w_6737f89', 'new_whale'}
# Duplicate images: ['11ba757f.jpg', '5988332d.jpg'], set of Ids: {'w_37bd99a'}
# Duplicate images: ['4bd5bedb.jpg', '5e467657.jpg'], set of Ids: {'w_2f6a962'}
# Duplicate images: ['a76fa33b.jpg', 'a97f7dca.jpg'], set of Ids: {'w_9ff699b'}
# Duplicate images: ['5e1e8352.jpg', 'a971c563.jpg'], set of Ids: {'w_aa3d7b8', 'new_whale'}
# Duplicate images: ['41361b5f.jpg', 'd8485b38.jpg'], set of Ids: {'w_63035d1', 'new_whale'}
# Duplicate images: ['47ef9b09.jpg', 'd5bc522c.jpg'], set of Ids: {'w_987a36f'}
# Duplicate images: ['38ee81ee.jpg', '6ccdd299.jpg'], set of Ids: {'w_fa32440'}
# Duplicate images: ['0c35fcb4.jpg', '2d6610b9.jpg'], set of Ids: {'w_7028d77', 'w_f6bca7a'}
# Duplicate images: ['651da09e.jpg', 'b79447a8.jpg'], set of Ids: {'w_8d83172'}
# Duplicate images: ['18558991.jpg', 'f5930905.jpg'], set of Ids: {'w_a0ae961'}
# Duplicate images: ['6b02f6df.jpg', '7b69408e.jpg'], set of Ids: {'w_2b0028d'}
# Duplicate images: ['41d00b14.jpg', 'd2301f4c.jpg'], set of Ids: {'w_dcb1f2a'}
# Duplicate images: ['aa70c3a4.jpg', 'ba72799e.jpg'], set of Ids: {'w_7185713', 'new_whale'}
# Duplicate images: ['0fddb687.jpg', 'a200a409.jpg'], set of Ids: {'w_01a51a6'}
# Duplicate images: ['0b02fbcd.jpg', '464abd87.jpg'], set of Ids: {'w_0e96943'}
# Duplicate images: ['6020a141.jpg', '7dea560c.jpg'], set of Ids: {'w_b8fdb8e', 'new_whale'}
# Duplicate images: ['1a9387da.jpg', '83da62d0.jpg'], set of Ids: {'w_49bbc79'}
# Duplicate images: ['70e2e892.jpg', '974961a4.jpg'], set of Ids: {'w_fd587bc'}
# Duplicate images: ['ab988b3e.jpg', 'b23d1ca7.jpg'], set of Ids: {'w_d62128e', 'new_whale'}
# Duplicate images: ['bb0f69b3.jpg', 'fb93a9ab.jpg'], set of Ids: {'w_44cccf6'}
# Duplicate images: ['95ae6f54.jpg', 'a3f2668f.jpg'], set of Ids: {'w_c0cfd5b'}
# Duplicate images: ['40d1b9cd.jpg', '4c7d8b01.jpg'], set of Ids: {'new_whale', 'w_e7a238b'}
# Duplicate images: ['70f6957b.jpg', '826afc50.jpg'], set of Ids: {'w_3411b9f'}
# Duplicate images: ['0a552569.jpg', '83dc3b84.jpg'], set of Ids: {'w_462a117'}
# Duplicate images: ['6088adf2.jpg', '7c0e716f.jpg'], set of Ids: {'w_48dd419'}
# Duplicate images: ['3e08fa34.jpg', 'e429da12.jpg'], set of Ids: {'w_d0157fd', 'new_whale'}
# Duplicate images: ['726cbeac.jpg', 'bd65d3ef.jpg'], set of Ids: {'w_a7f3698'}
# Duplicate images: ['334343c9.jpg', 'f1bebb68.jpg'], set of Ids: {'w_cc22f68', 'w_80bae3a'}
# Duplicate images: ['0cef66af.jpg', 'ea07e2b1.jpg'], set of Ids: {'w_f9a09c6'}
# Duplicate images: ['4210de9f.jpg', 'ea205889.jpg'], set of Ids: {'w_d7de1ee'}
# Duplicate images: ['7ae3e3c7.jpg', '96b8b6ea.jpg'], set of Ids: {'w_7f81114'}
# Duplicate images: ['0042ea34.jpg', '7f60c0a8.jpg'], set of Ids: {'w_968f2ca'}
# Duplicate images: ['7ddecfc2.jpg', '8f7cf1d4.jpg'], set of Ids: {'w_9548fcf', 'new_whale'}
# Duplicate images: ['c37390cf.jpg', 'f0467032.jpg'], set of Ids: {'w_bf4880a'}
# Duplicate images: ['0031c258.jpg', 'f130cb7d.jpg'], set of Ids: {'w_aae82f8', 'new_whale'}
# Duplicate images: ['5c2600f8.jpg', 'c159eeba.jpg'], set of Ids: {'w_ca94288'}
# Duplicate images: ['bcf56bfe.jpg', 'd71be0d5.jpg'], set of Ids: {'w_1a70685', 'new_whale'}
# Duplicate images: ['3b5c89ac.jpg', '556786d7.jpg'], set of Ids: {'w_ffa78a5', 'new_whale'}
# Duplicate images: ['06f3cbf8.jpg', '22eb0560.jpg'], set of Ids: {'w_fc433f7'}
# Duplicate images: ['5ba934cd.jpg', 'f35ad9ab.jpg'], set of Ids: {'w_db5cc79'}
# Duplicate images: ['e9c18417.jpg', 'f92127ba.jpg'], set of Ids: {'w_f6fb689'}
# Duplicate images: ['762e22f2.jpg', 'ebf596a3.jpg'], set of Ids: {'w_5a81425'}
# Duplicate images: ['44eb9b89.jpg', '89299f74.jpg'], set of Ids: {'w_b0e05b1'}
# Duplicate images: ['2c9bbea5.jpg', 'f3c1b087.jpg'], set of Ids: {'w_c0560ac', 'new_whale'}
# Duplicate images: ['c29996d3.jpg', 'cf91da02.jpg'], set of Ids: {'w_ea2385d'}
# Duplicate images: ['4bcc7c1b.jpg', '6481b5bd.jpg'], set of Ids: {'w_8d300c3'}
# Duplicate images: ['34f1fcc2.jpg', '79bb7b6d.jpg'], set of Ids: {'w_8459e39'}
# Duplicate images: ['38bdae1b.jpg', '46ed6998.jpg'], set of Ids: {'w_47d2bc6'}
# Duplicate images: ['118a256c.jpg', 'f569c250.jpg'], set of Ids: {'w_8867074'}
# Duplicate images: ['c2089572.jpg', 'd878fbcd.jpg'], set of Ids: {'w_48a5b86'}
# Duplicate images: ['1b5feb2a.jpg', '8e3dd01a.jpg'], set of Ids: {'w_8c9ed42', 'new_whale'}
# Duplicate images: ['39013bb2.jpg', 'ce24559a.jpg'], set of Ids: {'w_16d1b32'}
# Duplicate images: ['7c2885bd.jpg', '9e77c15f.jpg'], set of Ids: {'w_8e23e4c'}
# Duplicate images: ['9eb3291e.jpg', 'db034c12.jpg'], set of Ids: {'w_2ef900c', 'new_whale'}
# Duplicate images: ['5ef59d14.jpg', 'b552ac42.jpg'], set of Ids: {'w_2cde7c0'}
# Duplicate images: ['981ec103.jpg', 'e5d8bc42.jpg'], set of Ids: {'w_f93d780'}
# Duplicate images: ['47dfa82d.jpg', 'b5f243f6.jpg'], set of Ids: {'w_4863ed9'}
# Duplicate images: ['7aa1ee70.jpg', '88ac744a.jpg'], set of Ids: {'w_587d2e3'}
# Duplicate images: ['7198ba4d.jpg', 'f3a28620.jpg'], set of Ids: {'w_64f3545'}
# Duplicate images: ['a7ac40db.jpg', 'f340d081.jpg'], set of Ids: {'w_ad87135'}
# Duplicate images: ['65575c28.jpg', '78a24a5d.jpg'], set of Ids: {'w_7311fe4'}
# Duplicate images: ['5491a024.jpg', '5f7a514b.jpg'], set of Ids: {'w_25871da'}
# Duplicate images: ['1fb7e4c9.jpg', 'caa47c57.jpg'], set of Ids: {'w_67fecca'}
# Duplicate images: ['b8c17d84.jpg', 'f621cd02.jpg'], set of Ids: {'w_0aae8c1'}
# Duplicate images: ['942821f4.jpg', 'd4d69698.jpg'], set of Ids: {'w_72e70e5'}
# Duplicate images: ['2deae191.jpg', '2f0e52ab.jpg'], set of Ids: {'w_62c3998'}
# Duplicate images: ['391ae1f9.jpg', '42e24810.jpg'], set of Ids: {'w_06972d2', 'new_whale'}
# Duplicate images: ['5281c01f.jpg', 'e3074aa4.jpg'], set of Ids: {'w_cb2f78e', 'new_whale'}
# Duplicate images: ['5bf1890e.jpg', 'bbfef63f.jpg'], set of Ids: {'w_5d96ba4'}
# Duplicate images: ['70abfe1a.jpg', '7c8e1df9.jpg'], set of Ids: {'w_1da7080'}
# Duplicate images: ['c6cef315.jpg', 'e4ff0444.jpg'], set of Ids: {'w_813c5be'}
# Duplicate images: ['03933dbb.jpg', 'eea93983.jpg'], set of Ids: {'w_18eee6e', 'new_whale'}
# Duplicate images: ['03d0f974.jpg', '057d24dd.jpg'], set of Ids: {'w_cf3c233'}
# Duplicate images: ['1d22d565.jpg', '7b32738c.jpg'], set of Ids: {'w_33973bf'}
# Duplicate images: ['095e2b1a.jpg', 'b89eaf81.jpg'], set of Ids: {'w_b6c4efa'}
# Duplicate images: ['1420c4a3.jpg', '78cf322c.jpg'], set of Ids: {'w_e55a554'}
# Duplicate images: ['84bf94be.jpg', 'e1a47a8e.jpg'], set of Ids: {'w_f7e6199'}
# Duplicate images: ['1ec8d7f2.jpg', 'e976465c.jpg'], set of Ids: {'w_e9cacbf'}
# Duplicate images: ['219b9d5b.jpg', 'c7996a54.jpg'], set of Ids: {'w_7028d77', 'new_whale'}
# Duplicate images: ['822a934a.jpg', 'd2a2a406.jpg'], set of Ids: {'w_6c2d7ea'}
# Duplicate images: ['52e77268.jpg', '7c2907b2.jpg'], set of Ids: {'w_654a5bb'}
# Duplicate images: ['76caefe3.jpg', 'eb1b7327.jpg'], set of Ids: {'w_075aa6e'}
# Duplicate images: ['7310c41a.jpg', 'af079b53.jpg'], set of Ids: {'w_5436d75', 'new_whale'}
# Duplicate images: ['32aba2a8.jpg', '90fa288c.jpg'], set of Ids: {'w_9b401eb', 'new_whale'}
# Duplicate images: ['dec35330.jpg', 'ff3c2c25.jpg'], set of Ids: {'w_f5eb6c6'}
# Duplicate images: ['244cd83c.jpg', 'd827fba7.jpg'], set of Ids: {'w_d398969', 'new_whale'}
# Duplicate images: ['a60936fb.jpg', 'b756d005.jpg'], set of Ids: {'w_f1a4389'}
# Duplicate images: ['c31459be.jpg', 'ec506248.jpg'], set of Ids: {'w_bb2d34d', 'new_whale'}
# Duplicate images: ['26bbcb80.jpg', 'f821ec82.jpg'], set of Ids: {'w_4659acf'}
# Duplicate images: ['b158abdc.jpg', 'fe937459.jpg'], set of Ids: {'w_b34793e', 'new_whale'}
# Duplicate images: ['1ae3f511.jpg', '8ce76469.jpg'], set of Ids: {'w_95874a5'}
# Duplicate images: ['51166a0b.jpg', 'a0d319cb.jpg'], set of Ids: {'w_ca94288'}
# Duplicate images: ['3bc2a5ca.jpg', 'b0109f7e.jpg'], set of Ids: {'w_e80641a'}
# Duplicate images: ['07c0c8c2.jpg', '746f83a9.jpg'], set of Ids: {'w_ec354a5'}
# Duplicate images: ['1442f41d.jpg', '67ce9238.jpg'], set of Ids: {'w_4f38350'}
# Duplicate images: ['83d50b85.jpg', 'e1eba938.jpg'], set of Ids: {'w_91572bb', 'new_whale'}
# Duplicate images: ['72dedcc9.jpg', 'abbed544.jpg'], set of Ids: {'w_03ed3de', 'new_whale'}
# Duplicate images: ['02d235f7.jpg', '36e45ae5.jpg'], set of Ids: {'w_511c464'}
# Duplicate images: ['0870fa6b.jpg', '40507133.jpg'], set of Ids: {'w_ba8c7bc'}
# Duplicate images: ['3a32c24d.jpg', 'a1dc28be.jpg'], set of Ids: {'w_18df014'}
# Duplicate images: ['294ddef1.jpg', '6acdcb00.jpg'], set of Ids: {'w_eff7e35'}
# Duplicate images: ['068ddcd9.jpg', '0e861f4b.jpg'], set of Ids: {'w_b96d4e0'}
# Duplicate images: ['0ab00a28.jpg', '1ac3567c.jpg'], set of Ids: {'w_7104905'}
# Duplicate images: ['89bd6fd9.jpg', 'aff0b9c2.jpg'], set of Ids: {'w_cf092f5'}
# Duplicate images: ['5a3f0084.jpg', '87ec06b2.jpg'], set of Ids: {'w_ad3dd0b', 'new_whale'}
# Duplicate images: ['9529dfe3.jpg', 'e0030e15.jpg'], set of Ids: {'w_f75302f', 'new_whale'}
# Duplicate images: ['04ad14b2.jpg', 'd4707926.jpg'], set of Ids: {'w_c0d494d', 'new_whale'}
# Duplicate images: ['d11b57b4.jpg', 'ef9f23dc.jpg'], set of Ids: {'w_372ae75'}
# Duplicate images: ['59b5781f.jpg', '8caf404f.jpg'], set of Ids: {'w_bb2d34d', 'new_whale'}
# Duplicate images: ['30700f5c.jpg', '81bf3718.jpg'], set of Ids: {'w_cce912e'}
# Duplicate images: ['70944341.jpg', '8087f977.jpg'], set of Ids: {'w_12c3d3d'}
# Duplicate images: ['b373ccf9.jpg', 'd3050057.jpg'], set of Ids: {'new_whale'}
# Duplicate images: ['7a2764de.jpg', '946024d1.jpg'], set of Ids: {'w_beb62cc'}
# Duplicate images: ['71afa981.jpg', '847238a3.jpg'], set of Ids: {'w_813c5be', 'new_whale'}
# Duplicate images: ['45e9a0d9.jpg', 'd508ea16.jpg'], set of Ids: {'w_64830fa'}
# Duplicate images: ['e96671d9.jpg', 'fc226174.jpg'], set of Ids: {'w_d037229'}
# Duplicate images: ['163e7a25.jpg', 'beba228a.jpg'], set of Ids: {'w_b478c13', 'new_whale'}
# Duplicate images: ['7679680d.jpg', '885dcbfc.jpg'], set of Ids: {'w_f0d8be1'}
# Duplicate images: ['1cd1288b.jpg', 'cab2d23d.jpg'], set of Ids: {'w_993d66c'}
# Duplicate images: ['5c4a0864.jpg', 'afeed920.jpg'], set of Ids: {'w_9d704ab'}
# Duplicate images: ['6f3b1c6d.jpg', '82987a45.jpg'], set of Ids: {'w_da2efe0'}
# Duplicate images: ['6d37a125.jpg', 'f3c17f2a.jpg'], set of Ids: {'w_cf00b01'}
# Duplicate images: ['19d70c47.jpg', 'a80c305c.jpg'], set of Ids: {'w_97bc172', 'new_whale'}
# Duplicate images: ['0c4f7a83.jpg', 'e01b056d.jpg'], set of Ids: {'w_1090920'}
# Duplicate images: ['3dc50b96.jpg', '8c99c43f.jpg'], set of Ids: {'w_6d17527'}
# Duplicate images: ['685c3732.jpg', '8827f71e.jpg'], set of Ids: {'w_2d99a0c'}
# Duplicate images: ['375a73bd.jpg', 'd29a047b.jpg'], set of Ids: {'w_73b705e'}
# Duplicate images: ['1b87678b.jpg', 'b657208c.jpg'], set of Ids: {'w_3add848'}
# Duplicate images: ['84bd38f3.jpg', 'c398d294.jpg'], set of Ids: {'w_7c18f3c', 'new_whale'}
# Duplicate images: ['5d7102b4.jpg', '64b9e47d.jpg'], set of Ids: {'w_41ed8e8'}
# Duplicate images: ['432f627b.jpg', 'c9213ad9.jpg'], set of Ids: {'w_83714b7'}
# Duplicate images: ['19e2b8fd.jpg', '43fbabbb.jpg'], set of Ids: {'w_2071a4c'}
# Duplicate images: ['37544081.jpg', '3a831f39.jpg'], set of Ids: {'w_d6df554'}
# Duplicate images: ['b7f01086.jpg', 'd60ecdd5.jpg'], set of Ids: {'w_3039e7a', 'new_whale'}
# Duplicate images: ['5ac4811d.jpg', '6415a7b6.jpg'], set of Ids: {'w_17d5eb9'}
# Duplicate images: ['8d4b7dc2.jpg', '9f569a7d.jpg'], set of Ids: {'w_0c70bc3'}
# Duplicate images: ['2862d1bf.jpg', '7df73caa.jpg'], set of Ids: {'w_d6815ff'}
# Duplicate images: ['660e39f4.jpg', '8df52ebd.jpg'], set of Ids: {'w_92be3ca', 'new_whale'}
# Duplicate images: ['5bba3adb.jpg', '636e2e2e.jpg'], set of Ids: {'w_a59905f'}
# Duplicate images: ['2496a4a9.jpg', 'af9895ae.jpg'], set of Ids: {'w_a965f14'}
# Duplicate images: ['76a22476.jpg', 'a2166492.jpg'], set of Ids: {'w_cdc21df', 'new_whale'}
# Duplicate images: ['2b624b95.jpg', 'b162ff51.jpg'], set of Ids: {'w_d6df554'}
# Duplicate images: ['4872bc99.jpg', 'cfa397ce.jpg'], set of Ids: {'w_d4b90bf', 'new_whale'}
# Duplicate images: ['5819cda8.jpg', '6d0c73c3.jpg'], set of Ids: {'w_7f999ff'}
# Duplicate images: ['9c6b6854.jpg', 'dabfedb4.jpg'], set of Ids: {'w_865c2ba'}
# Duplicate images: ['1933258b.jpg', '9ea6371c.jpg'], set of Ids: {'w_7dee51b', 'new_whale'}
# Duplicate images: ['c9eb013e.jpg', 'e461d6a3.jpg'], set of Ids: {'w_dff77b6'}
# Duplicate images: ['01d4467a.jpg', 'dd698de6.jpg'], set of Ids: {'w_4114553'}
# Duplicate images: ['1bfd386e.jpg', '63644a5e.jpg'], set of Ids: {'w_693c9ee'}
# Duplicate images: ['177c6621.jpg', 'f820e4e2.jpg'], set of Ids: {'w_7a2dfd7'}
# Duplicate images: ['8bface5d.jpg', '988eed9e.jpg'], set of Ids: {'w_9741f42'}
# Duplicate images: ['48c51cc5.jpg', '9a8496a0.jpg'], set of Ids: {'w_f843c4d', 'w_90201e3'}
# Duplicate images: ['68e728c6.jpg', 'e2b825f5.jpg'], set of Ids: {'w_47d2bc6'}
# Duplicate images: ['08b9dae5.jpg', '502c2aeb.jpg'], set of Ids: {'w_90f5d3b'}
# Duplicate images: ['519b4899.jpg', 'db366dee.jpg'], set of Ids: {'w_5f9508d'}
# Duplicate images: ['4f7e290b.jpg', 'dbbb944f.jpg'], set of Ids: {'w_d0157fd'}
# Duplicate images: ['bd13080e.jpg', 'e20e9323.jpg'], set of Ids: {'w_19a5685'}
# Duplicate images: ['c7c249d8.jpg', 'd915fc69.jpg'], set of Ids: {'w_309a2b3'}
# Duplicate images: ['4d732f4d.jpg', '9146fcf3.jpg'], set of Ids: {'w_12cdfbd'}
# Duplicate images: ['01ed89f6.jpg', 'dbc23cf3.jpg'], set of Ids: {'w_67de30b'}
# Duplicate images: ['29c82382.jpg', 'ee1cfa3c.jpg'], set of Ids: {'w_045d9fc', 'new_whale'}
# Duplicate images: ['22fae40e.jpg', '4f04f6dd.jpg'], set of Ids: {'w_e3c1ec4'}
# Duplicate images: ['91b704dc.jpg', 'db147df2.jpg'], set of Ids: {'w_1287fbc'}
# Duplicate images: ['9eff28cf.jpg', 'a9040398.jpg'], set of Ids: {'w_ddbf533'}
# Duplicate images: ['2407e5ff.jpg', '8982cf4f.jpg'], set of Ids: {'w_dcd7a1d', 'new_whale'}
# Duplicate images: ['4498fd8f.jpg', '7f178d4e.jpg'], set of Ids: {'w_3d66298'}
# Duplicate images: ['4bff4df8.jpg', 'ad91dcba.jpg'], set of Ids: {'w_b9417ee'}
# Duplicate images: ['70cd3cf2.jpg', 'be9d047d.jpg'], set of Ids: {'w_5c07f42', 'new_whale'}
# Duplicate images: ['9cbc9f7f.jpg', 'bc803c71.jpg'], set of Ids: {'w_964c1b3', 'new_whale'}
# Duplicate images: ['008809b5.jpg', '169f97c9.jpg'], set of Ids: {'w_7e5cc5e'}
# Duplicate images: ['a1c1e3bf.jpg', 'ab696c9e.jpg'], set of Ids: {'w_fab0a22'}
# Duplicate images: ['4d5ecf39.jpg', '50efe91d.jpg'], set of Ids: {'w_bb388ca'}
# Duplicate images: ['a23d95cc.jpg', 'f2fb64c2.jpg'], set of Ids: {'w_715d152'}
# Duplicate images: ['80e8b045.jpg', 'fca04935.jpg'], set of Ids: {'w_2a9727c'}
# Duplicate images: ['0fbc91d1.jpg', 'ba31083d.jpg'], set of Ids: {'w_d5ec83f'}
# Duplicate images: ['cfb80d51.jpg', 'f14d00cf.jpg'], set of Ids: {'w_dee1df3'}
# Duplicate images: ['145ae13e.jpg', '2cff7662.jpg'], set of Ids: {'w_19f0b15'}
# Duplicate images: ['15ffb96b.jpg', 'fc14e6c2.jpg'], set of Ids: {'w_d0e5d1d'}
# Duplicate images: ['6519746e.jpg', 'd895ed09.jpg'], set of Ids: {'w_1b6d34d', 'new_whale'}
# Duplicate images: ['32d9e0da.jpg', '51944888.jpg'], set of Ids: {'w_8c1e2e4'}
# Duplicate images: ['7d7c4a84.jpg', 'e07c08cd.jpg'], set of Ids: {'w_89d9c03'}
# Duplicate images: ['43577066.jpg', 'c7d8a3ee.jpg'], set of Ids: {'w_d382236'}
# Duplicate images: ['4425522f.jpg', '9fd688bc.jpg'], set of Ids: {'w_b3e6069'}
# Duplicate images: ['c1bd0ce1.jpg', 'fc5000ba.jpg'], set of Ids: {'w_d6255a4'}
# Duplicate images: ['687abfb4.jpg', 'b70b16f3.jpg'], set of Ids: {'w_5797d05', 'new_whale'}
# Duplicate images: ['2f527a19.jpg', 'd3dc6abc.jpg'], set of Ids: {'w_62c3998'}
# Duplicate images: ['27fecff5.jpg', 'd8e3cd8a.jpg'], set of Ids: {'w_aa7a302'}
# Duplicate images: ['3bffce36.jpg', '9ea28e8f.jpg'], set of Ids: {'w_7b035cc'}
# Duplicate images: ['32f027c4.jpg', 'c2f49fc2.jpg'], set of Ids: {'w_62c548b'}
# Duplicate images: ['1712f71a.jpg', '19b4298e.jpg'], set of Ids: {'w_bed6af1'}
# Duplicate images: ['39530e00.jpg', '43e54d2d.jpg'], set of Ids: {'w_40323ac'}
# Duplicate images: ['84f78c93.jpg', '8c94a8d0.jpg'], set of Ids: {'w_7b035cc'}
# Duplicate images: ['40c9509b.jpg', 'a6b79cb9.jpg'], set of Ids: {'w_ee948c6'}
# Duplicate images: ['b0847702.jpg', 'ff38054f.jpg'], set of Ids: {'w_6734e40'}
# Duplicate images: ['285a9e26.jpg', '780956c8.jpg'], set of Ids: {'w_dbaa2b1'}
# Duplicate images: ['5b9748b5.jpg', '9e607676.jpg'], set of Ids: {'w_6734e40', 'new_whale'}
# Duplicate images: ['00ec0dcd.jpg', '352d8e07.jpg'], set of Ids: {'w_a2eb1bb'}
# Duplicate images: ['522e341a.jpg', 'c31155ef.jpg'], set of Ids: {'w_c0d1701'}
# Duplicate images: ['7a97472d.jpg', '95dad5f3.jpg'], set of Ids: {'w_3f365f3'}
# Duplicate images: ['4600ab84.jpg', '83c66c07.jpg'], set of Ids: {'w_cbd271b', 'new_whale'}
# Duplicate images: ['779ac19c.jpg', 'e30d9525.jpg'], set of Ids: {'w_e826a6f'}
# Duplicate images: ['21db85f5.jpg', 'eac1a851.jpg'], set of Ids: {'w_c0d494d'}
# Duplicate images: ['98368264.jpg', '99f9cdcf.jpg'], set of Ids: {'w_60eba40'}
# Duplicate images: ['28781a20.jpg', 'a7dc6c84.jpg'], set of Ids: {'w_5c62a56'}
# Duplicate images: ['a5143f10.jpg', 'edf906b0.jpg'], set of Ids: {'w_4a78bf2'}
# Duplicate images: ['350fc390.jpg', '7566d3af.jpg'], set of Ids: {'w_76b6f7c'}
# Duplicate images: ['55a53eac.jpg', '717554b6.jpg'], set of Ids: {'w_f660d7d', 'w_6af9dd7'}
# Duplicate images: ['52bb8276.jpg', 'da327b03.jpg'], set of Ids: {'w_2e872af'}
# Duplicate images: ['2a4710d5.jpg', '50101bdb.jpg'], set of Ids: {'w_30f095d'}
# Duplicate images: ['ae11f796.jpg', 'db8356fb.jpg'], set of Ids: {'w_83df8d5'}
# Duplicate images: ['04b16181.jpg', '59278e06.jpg'], set of Ids: {'w_b83b069'}
# Duplicate images: ['01cf2e2e.jpg', '01dd608b.jpg'], set of Ids: {'w_12c3d3d', 'new_whale'}
# Duplicate images: ['a596311e.jpg', 'fcc8d828.jpg'], set of Ids: {'w_abe383e'}
# Duplicate images: ['88f6e371.jpg', 'f796599e.jpg'], set of Ids: {'w_07e92ee', 'new_whale'}
# Duplicate images: ['16dad39c.jpg', '970cf3bc.jpg'], set of Ids: {'w_f87b77b', 'new_whale'}
# Duplicate images: ['6ff6bc5b.jpg', 'f6845075.jpg'], set of Ids: {'w_29fc831'}
# Duplicate images: ['3535398b.jpg', '9f24f879.jpg'], set of Ids: {'w_6e8486d'}
# Duplicate images: ['4f100e91.jpg', 'caf91ef9.jpg'], set of Ids: {'w_08d1ccd'}
# Duplicate images: ['64d23428.jpg', '950b9112.jpg'], set of Ids: {'w_099ab25'}
# Duplicate images: ['8333caf8.jpg', 'ce5d7032.jpg'], set of Ids: {'w_e5250e9'}
# Duplicate images: ['974dc5fc.jpg', '9f32d836.jpg'], set of Ids: {'w_96c141f', 'new_whale'}
# Duplicate images: ['372fb923.jpg', '8ce06fc5.jpg'], set of Ids: {'w_3d66298'}
# Duplicate images: ['68bd9c27.jpg', 'f84b686c.jpg'], set of Ids: {'w_3fe1eb9'}
# Duplicate images: ['6395a7f5.jpg', 'ef825832.jpg'], set of Ids: {'w_62c3998', 'new_whale'}
# Duplicate images: ['02af1aa3.jpg', '0aa416d8.jpg'], set of Ids: {'w_5624f08'}
# Duplicate images: ['658ea2c7.jpg', 'b220e464.jpg'], set of Ids: {'w_1e3ce01'}
# Duplicate images: ['59e815e4.jpg', '5f8d830b.jpg'], set of Ids: {'w_a11d17e'}
# Duplicate images: ['25d35d69.jpg', '6febd732.jpg'], set of Ids: {'w_2f7753e'}
# Duplicate images: ['12c67e49.jpg', 'c4b7e7db.jpg'], set of Ids: {'w_38e4aae'}
# Duplicate images: ['e17dad77.jpg', 'f17b9666.jpg'], set of Ids: {'w_3a7d86d'}
# Duplicate images: ['196d9d20.jpg', 'cef80cb0.jpg'], set of Ids: {'w_861cc1c'}
# Duplicate images: ['04867dab.jpg', 'f88cbd4d.jpg'], set of Ids: {'w_5cb5fc3'}
# Duplicate images: ['738f3370.jpg', 'a314019f.jpg'], set of Ids: {'w_e30e97f'}
# Duplicate images: ['a1e914d7.jpg', 'd1a1c1c0.jpg'], set of Ids: {'w_a06bdc4', 'new_whale'}
# Duplicate images: ['52a6d0c3.jpg', 'd14090c9.jpg'], set of Ids: {'w_4041a7b'}
# Duplicate images: ['1417b473.jpg', '5620cd80.jpg'], set of Ids: {'w_159f36b'}
# Duplicate images: ['19035b3c.jpg', '71235829.jpg'], set of Ids: {'w_a365757', 'new_whale'}
# Duplicate images: ['56f09cf7.jpg', 'a478ef7b.jpg'], set of Ids: {'w_28fa29e'}
# Duplicate images: ['2c3b34a3.jpg', '3cdd7fa7.jpg'], set of Ids: {'w_1287fbc'}
# Duplicate images: ['2ed1414f.jpg', 'd9fd554a.jpg'], set of Ids: {'w_e73d83c'}
# Duplicate images: ['133b2214.jpg', '2027722b.jpg'], set of Ids: {'w_93aee9e'}
# Duplicate images: ['94fdd35d.jpg', 'c145f961.jpg'], set of Ids: {'w_703e39b'}
# Duplicate images: ['6dbafffe.jpg', 'ed9f6964.jpg'], set of Ids: {'w_881f3c4', 'new_whale'}
# Duplicate images: ['0dc4a773.jpg', 'ade0c465.jpg'], set of Ids: {'w_5c6215c'}
# Duplicate images: ['7fce2c3f.jpg', 'c3caa1d3.jpg'], set of Ids: {'w_4e52a49'}
# Duplicate images: ['04cdb743.jpg', '60dc9e20.jpg'], set of Ids: {'w_ad8bc47'}
# Duplicate images: ['602901f8.jpg', 'c4c7ee80.jpg'], set of Ids: {'w_c1e8594'}
# Duplicate images: ['02916b71.jpg', '23625ee7.jpg'], set of Ids: {'w_73d5489'}
# Duplicate images: ['6fc67854.jpg', '9b05957d.jpg'], set of Ids: {'w_d09e61a'}
# Duplicate images: ['34881b32.jpg', 'f17f76c3.jpg'], set of Ids: {'w_9b401eb', 'new_whale'}
# Duplicate images: ['8e8d1b22.jpg', 'bfdddcad.jpg'], set of Ids: {'new_whale', 'w_ab4cae2'}
# Duplicate images: ['8e6cd7f4.jpg', 'caa04386.jpg'], set of Ids: {'w_97bc172', 'new_whale'}
# Duplicate images: ['376baa5c.jpg', '90565095.jpg'], set of Ids: {'w_76d2cce'}
# Duplicate images: ['56e63d4d.jpg', '87f3a6f0.jpg'], set of Ids: {'w_1d4f970'}
# Duplicate images: ['3e4a4574.jpg', '6ecce813.jpg'], set of Ids: {'new_whale', 'w_e63fbbe'}
# Duplicate images: ['ab9d8b8d.jpg', 'ae5abd6a.jpg'], set of Ids: {'w_aed1e43'}
# Duplicate images: ['613cbac6.jpg', '7b2b98f5.jpg'], set of Ids: {'w_64433af', 'new_whale'}
# Duplicate images: ['3f5b3e6e.jpg', 'a1e5a5e8.jpg'], set of Ids: {'w_7895123'}
# Duplicate images: ['b1d889f8.jpg', 'eb6fcb47.jpg'], set of Ids: {'w_3e1ba5b'}
# Duplicate images: ['4d64dac6.jpg', 'e42b4e9b.jpg'], set of Ids: {'w_17a2610', 'new_whale'}
# Duplicate images: ['7f7c3b84.jpg', 'c4ccb22a.jpg'], set of Ids: {'w_17ee910'}
# Duplicate images: ['25c9e881.jpg', 'a7a4a18e.jpg'], set of Ids: {'w_5ba417d', 'new_whale'}
# Duplicate images: ['0c290363.jpg', '3322aa7c.jpg'], set of Ids: {'w_b29214f'}
# Duplicate images: ['2c2a91c0.jpg', 'cbc40e82.jpg'], set of Ids: {'w_1a229eb'}
# Duplicate images: ['4e37d286.jpg', '610241d4.jpg'], set of Ids: {'w_8e451d9'}
# Duplicate images: ['68776b72.jpg', '84e9b373.jpg'], set of Ids: {'w_9868b95'}
# Duplicate images: ['5d2c69ae.jpg', '99e6f6a0.jpg'], set of Ids: {'w_86e5d8c'}
# Duplicate images: ['8083a4af.jpg', 'a77f4d68.jpg'], set of Ids: {'w_fd1308e'}
# Duplicate images: ['e7c1c10f.jpg', 'fac671ec.jpg'], set of Ids: {'w_def715a'}
# Duplicate images: ['85140821.jpg', 'cd274fb6.jpg'], set of Ids: {'w_fdf60bb'}
# Duplicate images: ['69d946a0.jpg', '77ccf90d.jpg'], set of Ids: {'w_e700deb'}
# Duplicate images: ['3cb1fd98.jpg', 'bdcdff28.jpg'], set of Ids: {'w_9b401eb'}
# Duplicate images: ['239c83c2.jpg', '73332aa2.jpg'], set of Ids: {'w_54c00ad', 'new_whale'}
# Duplicate images: ['2e8b0594.jpg', '34b06b3b.jpg'], set of Ids: {'w_516bedb'}
# Duplicate images: ['44522955.jpg', '880ba235.jpg'], set of Ids: {'w_cef690d'}
# Duplicate images: ['040e5bd6.jpg', '3c2540c3.jpg'], set of Ids: {'w_86b3de4'}
# Duplicate images: ['70a02704.jpg', '8eb5b714.jpg'], set of Ids: {'w_ee17a08', 'new_whale'}
# Duplicate images: ['3680d686.jpg', '43e9dd06.jpg'], set of Ids: {'w_503ff17'}
# Duplicate images: ['9ecb6f18.jpg', 'fd77aed8.jpg'], set of Ids: {'w_4b83ce2'}
# Duplicate images: ['2917ea35.jpg', 'd5d5d640.jpg'], set of Ids: {'w_1431f4b'}
# Duplicate images: ['a15a4cf7.jpg', 'fd696375.jpg'], set of Ids: {'w_5c6215c'}
# Duplicate images: ['1f2913e3.jpg', 'e19655a4.jpg'], set of Ids: {'w_1287fbc'}
# Duplicate images: ['377891df.jpg', '5266fa8b.jpg'], set of Ids: {'w_71bfc77'}
# Duplicate images: ['1cda3adf.jpg', '5b32f23a.jpg'], set of Ids: {'w_ffa78a5'}
# Duplicate images: ['7a2b22a6.jpg', '85d510c1.jpg'], set of Ids: {'w_3572e7e'}
# Duplicate images: ['a300e9ee.jpg', 'ef39639e.jpg'], set of Ids: {'w_1f6e1db', 'new_whale'}
# Duplicate images: ['a7b0c232.jpg', 'e0dfe525.jpg'], set of Ids: {'w_7311fe4'}
# Duplicate images: ['4f6fd0e9.jpg', '8614219d.jpg'], set of Ids: {'w_5570053', 'w_dbd2cff'}
# Duplicate images: ['c0a25e74.jpg', 'eb9499b4.jpg'], set of Ids: {'w_2a04ceb'}
# Duplicate images: ['0d6c23c0.jpg', 'c1e0d103.jpg'], set of Ids: {'w_01c2cb0'}
# Duplicate images: ['415b1533.jpg', '7933280d.jpg'], set of Ids: {'w_95aad92'}
# Duplicate images: ['7ac80e97.jpg', 'bc8719f4.jpg'], set of Ids: {'w_efebfe8'}
# Duplicate images: ['210756c2.jpg', 'abb34e87.jpg'], set of Ids: {'w_238bbbf'}
# Duplicate images: ['1990152d.jpg', '80e1ee26.jpg'], set of Ids: {'w_92d390e'}
# Duplicate images: ['87cb279c.jpg', 'a4f8b446.jpg'], set of Ids: {'w_95874a5'}
# Duplicate images: ['417fa931.jpg', '54e24354.jpg'], set of Ids: {'w_95874a5', 'new_whale'}
# Duplicate images: ['c84489dc.jpg', 'd7eb44e1.jpg'], set of Ids: {'w_7852bd1', 'new_whale'}
# Duplicate images: ['735c1474.jpg', 'a0160b07.jpg'], set of Ids: {'w_b6ed5d2'}
# Duplicate images: ['1193f6c3.jpg', '2b0b0326.jpg'], set of Ids: {'w_7c943ab'}
# Duplicate images: ['47d88de7.jpg', 'feb32d26.jpg'], set of Ids: {'w_b17f9ea', 'new_whale'}
# Duplicate images: ['5844f3f2.jpg', '73bbaf2d.jpg'], set of Ids: {'w_94ba67d', 'new_whale'}
# Duplicate images: ['6e94af2b.jpg', 'd9ec40c0.jpg'], set of Ids: {'w_7e8b270'}
# Duplicate images: ['17b3ee24.jpg', '7d7e74e0.jpg'], set of Ids: {'w_17b33ae'}
# Duplicate images: ['3b522568.jpg', '66ebf418.jpg'], set of Ids: {'w_e38b2c7'}
# Duplicate images: ['430ca666.jpg', 'ccecf381.jpg'], set of Ids: {'w_c84551d'}
# Duplicate images: ['c6ab6e36.jpg', 'edaff6f0.jpg'], set of Ids: {'new_whale', 'w_76b6f7c'}
# Duplicate images: ['9f982966.jpg', 'e4f2c738.jpg'], set of Ids: {'w_a18d0dc'}
# Duplicate images: ['10a4fc3c.jpg', 'd158aa01.jpg'], set of Ids: {'w_7419e4b'}
# Duplicate images: ['613e6d76.jpg', 'fe5f33d6.jpg'], set of Ids: {'w_1969a9d'}
# Duplicate images: ['099035b0.jpg', '865a6f08.jpg'], set of Ids: {'w_d28208f'}
# Duplicate images: ['42b737be.jpg', 'da5cc3b3.jpg'], set of Ids: {'w_cf24f84'}
# Duplicate images: ['0376d91d.jpg', '868061cd.jpg'], set of Ids: {'w_1274a11', 'new_whale'}
# Duplicate images: ['6c3acbcc.jpg', '7808700d.jpg'], set of Ids: {'w_1489751'}
# Duplicate images: ['a6e913da.jpg', 'c080cee1.jpg'], set of Ids: {'w_daf162a'}
# Duplicate images: ['1247e239.jpg', '7fe190ce.jpg'], set of Ids: {'w_43b50e5'}
# Duplicate images: ['193ae7a0.jpg', 'f78e46dd.jpg'], set of Ids: {'w_5297ab3'}
# Duplicate images: ['60b08846.jpg', 'e5c12b88.jpg'], set of Ids: {'w_fb7a56b'}
# Duplicate images: ['1844225e.jpg', 'a3f7a82f.jpg'], set of Ids: {'w_daec6d3'}
# Duplicate images: ['1c35a699.jpg', 'e2c92c0e.jpg'], set of Ids: {'w_5ba417d'}
# Duplicate images: ['2b792814.jpg', '56fafc52.jpg'], set of Ids: {'w_d428980', 'w_cd88a48'}
# Duplicate images: ['7668456a.jpg', 'c84b0fdf.jpg'], set of Ids: {'w_1a5e7a2'}
# Duplicate images: ['88f719f3.jpg', 'a58e2a23.jpg'], set of Ids: {'w_02bb4cf'}
# Duplicate images: ['01692e13.jpg', 'e7a39cff.jpg'], set of Ids: {'w_2173953'}
# Duplicate images: ['738bce06.jpg', 'eb1bcb6c.jpg'], set of Ids: {'w_987a36f'}
# Duplicate images: ['1096053c.jpg', '9b80122b.jpg'], set of Ids: {'w_09dd18c'}
# Duplicate images: ['77727aa1.jpg', '982c3a6a.jpg'], set of Ids: {'w_bd43538'}
# Duplicate images: ['04c06689.jpg', '4ec53c22.jpg'], set of Ids: {'w_47d2bc6'}
# Duplicate images: ['10bc0024.jpg', 'b80e38cb.jpg'], set of Ids: {'w_7885601'}
# Duplicate images: ['d9c35b01.jpg', 'dc3f455e.jpg'], set of Ids: {'w_2071a4c'}
# Duplicate images: ['2d210495.jpg', 'db1d90b7.jpg'], set of Ids: {'w_715d152', 'new_whale'}
# Duplicate images: ['44672aeb.jpg', 'a412e7de.jpg'], set of Ids: {'w_3ee8570'}
# Duplicate images: ['41a4f2e7.jpg', '4ec7ba2d.jpg'], set of Ids: {'w_3e1ba5b'}
# Duplicate images: ['505f384d.jpg', 'c274df0d.jpg'], set of Ids: {'w_b7d5069'}
# Duplicate images: ['b3239d8d.jpg', 'f92cf61c.jpg'], set of Ids: {'w_64433af'}
# Duplicate images: ['07be1da5.jpg', '2fbfd185.jpg'], set of Ids: {'w_b9c9129'}
# Duplicate images: ['a9baefcc.jpg', 'f7bf8ae9.jpg'], set of Ids: {'w_e54feba', 'new_whale'}
# Duplicate images: ['198139ea.jpg', 'dbb23c96.jpg'], set of Ids: {'w_5966fff'}
# Duplicate images: ['03f8cf5a.jpg', '173ffdef.jpg'], set of Ids: {'w_b8f8e69'}
# Duplicate images: ['52f9b180.jpg', 'a7e40b9c.jpg'], set of Ids: {'w_a5431ca'}
# Duplicate images: ['67c185bc.jpg', 'cf2898d3.jpg'], set of Ids: {'w_143b201'}
# Duplicate images: ['aa64cbe2.jpg', 'bf51e07e.jpg'], set of Ids: {'w_0d8fb3f'}
# Duplicate images: ['5b68e47c.jpg', 'c7cee76e.jpg'], set of Ids: {'w_6545984', 'new_whale'}
# Duplicate images: ['40303bdf.jpg', '408124a8.jpg'], set of Ids: {'w_a2b8172'}
# Duplicate images: ['1c50a093.jpg', 'cb637e0c.jpg'], set of Ids: {'w_aa16da4'}
# Duplicate images: ['5941d006.jpg', 'f5d6cbdc.jpg'], set of Ids: {'w_c529cf1'}
# Duplicate images: ['8f1fb719.jpg', 'f5ac7c84.jpg'], set of Ids: {'w_1287fbc'}
# Duplicate images: ['8de897e9.jpg', 'd2f34e88.jpg'], set of Ids: {'w_aafa5b5'}
# Duplicate images: ['7b8d4ac0.jpg', 'ccc570bb.jpg'], set of Ids: {'w_2e4df76'}
# Duplicate images: ['1b51d186.jpg', 'ee2ef8d6.jpg'], set of Ids: {'w_014250a'}
# Duplicate images: ['087495e6.jpg', 'f1f13a10.jpg'], set of Ids: {'w_ff70408'}
# Duplicate images: ['77416232.jpg', '7cef34e9.jpg'], set of Ids: {'w_f5771d1'}
# Duplicate images: ['c8b91bf4.jpg', 'd58d40af.jpg'], set of Ids: {'w_3650949'}
# Duplicate images: ['00863b8c.jpg', 'e9813721.jpg'], set of Ids: {'w_bc93297', 'new_whale'}
# Duplicate images: ['37a34b39.jpg', 'a22924c4.jpg'], set of Ids: {'w_f746a73'}
# Duplicate images: ['c3f9e536.jpg', 'cca9cd4e.jpg'], set of Ids: {'w_b7d5069', 'w_da6d50b'}
# Duplicate images: ['97791473.jpg', 'abd863e3.jpg'], set of Ids: {'w_e3c119c'}
# Duplicate images: ['13d7baad.jpg', 'be5543ca.jpg'], set of Ids: {'w_90f5d3b'}
# Duplicate images: ['490a66f4.jpg', '75e189d4.jpg'], set of Ids: {'w_715c557'}
# Duplicate images: ['7952c17c.jpg', 'f8bcfd01.jpg'], set of Ids: {'w_32a920b'}
# Duplicate images: ['8d155118.jpg', 'd7936231.jpg'], set of Ids: {'w_ab1c859'}
# Duplicate images: ['810ca051.jpg', '8bb4b9a9.jpg'], set of Ids: {'w_33973bf'}
# Duplicate images: ['1a53e0a5.jpg', '5d3b3513.jpg'], set of Ids: {'w_2dbb0fe'}
# Duplicate images: ['c37f74c6.jpg', 'd0df591d.jpg'], set of Ids: {'w_9947243'}
# Duplicate images: ['a6d0e8a5.jpg', 'f68bb972.jpg'], set of Ids: {'w_9b401eb'}
# Duplicate images: ['5a6291f9.jpg', 'a7b1a40d.jpg'], set of Ids: {'w_9b401eb'}
# Duplicate images: ['10807a6e.jpg', '9539a505.jpg'], set of Ids: {'w_62c3998', 'new_whale'}
# Duplicate images: ['cebf233a.jpg', 'e90a072d.jpg'], set of Ids: {'w_741861e', 'new_whale'}
# Duplicate images: ['44134aec.jpg', '4a640733.jpg'], set of Ids: {'w_49bbc79', 'new_whale'}
# Duplicate images: ['357a2cb7.jpg', '43eaae52.jpg'], set of Ids: {'w_303518a'}
# Duplicate images: ['0c11fa0c.jpg', '7f7702dc.jpg'], set of Ids: {'w_53859b2', 'new_whale'}
# Duplicate images: ['a1f417a0.jpg', 'e5fe87a4.jpg'], set of Ids: {'w_8c1e2e4'}
# Duplicate images: ['97acf51b.jpg', 'c4452d8d.jpg'], set of Ids: {'w_5f50b5e'}
# Duplicate images: ['1b37d75e.jpg', '80df837b.jpg'], set of Ids: {'w_c0f3e88', 'new_whale'}
# Duplicate images: ['04b3714e.jpg', 'f6a912ad.jpg'], set of Ids: {'w_37dd956'}
# Number of 'new whale' in duplicate images: 175
# Number of duplicates: 419
# Number of _duplicates: 1555

# %%
removeInconsistentData(train_input, TARGET_CSV_FILE, TARGET_IMG_PATH)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9a32898337af> in <module>()
# ----> 1 removeInconsistentData(train_input, TARGET_CSV_FILE, TARGET_IMG_PATH)
#
# <ipython-input-6-e71b9aa84644> in removeInconsistentData(dataWithHash, targetCSVFile, targetImageFolder, newWhaleOnly)
#      98
#      99     # remove images
# --> 100     for imagePath in dataWithHash.loc[dataWithHash.index.isin(toRemove)].Image.tolist():
#     101         os.remove(os.path.join(targetImageFolder, imagePath))
#     102
#
# NameError: name 'toRemove' is not defined

# %%
removeDuplicateData(train_input, TARGET_CSV_FILE, TARGET_IMG_PATH)

# %%
showDuplicateData(train_input, False)
# Out:
# Duplicate images: ['00863b8c.jpg', 'e9813721.jpg'], set of Ids: {'w_bc93297', 'new_whale'}
# Duplicate images: ['0376d91d.jpg', '868061cd.jpg'], set of Ids: {'w_1274a11', 'new_whale'}
# Duplicate images: ['27627742.jpg', '36118167.jpg'], set of Ids: {'w_fd3ce71', 'new_whale'}
# Duplicate images: ['5b68e47c.jpg', 'c7cee76e.jpg'], set of Ids: {'w_6545984', 'new_whale'}
# Duplicate images: ['0c88a7aa.jpg', '6699001e.jpg'], set of Ids: {'w_d36f58c', 'new_whale'}
# Duplicate images: ['7310c41a.jpg', 'af079b53.jpg'], set of Ids: {'w_5436d75', 'new_whale'}
# Duplicate images: ['02c8235c.jpg', 'dcc5b795.jpg'], set of Ids: {'w_e59a1f0', 'new_whale'}
# Duplicate images: ['024144e5.jpg', 'e17384fd.jpg'], set of Ids: {'w_0f16be3', 'new_whale'}
# Duplicate images: ['451c8b8f.jpg', 'e940bee9.jpg'], set of Ids: {'w_02bb4cf', 'new_whale'}
# Duplicate images: ['9cbc9f7f.jpg', 'bc803c71.jpg'], set of Ids: {'w_964c1b3', 'new_whale'}
# Duplicate images: ['6ad9c4b8.jpg', '8a26e9f8.jpg'], set of Ids: {'w_44cccf6', 'new_whale'}
# Duplicate images: ['05f4fd87.jpg', 'bcb70ecd.jpg'], set of Ids: {'w_71e6583', 'new_whale'}
# Duplicate images: ['30ea3bfe.jpg', 'b28cc478.jpg'], set of Ids: {'w_88f57d0', 'new_whale'}
# Duplicate images: ['4ca241b1.jpg', '5f8d9492.jpg'], set of Ids: {'w_ef89416', 'new_whale'}
# Duplicate images: ['30d6aaa9.jpg', 'b3255607.jpg'], set of Ids: {'w_ee9c4d7', 'new_whale'}
# Duplicate images: ['34881b32.jpg', 'f17f76c3.jpg'], set of Ids: {'w_9b401eb', 'new_whale'}
# Duplicate images: ['200b53a2.jpg', '6fc557ed.jpg'], set of Ids: {'w_aa16da4', 'new_whale'}
# Duplicate images: ['01cf2e2e.jpg', '01dd608b.jpg'], set of Ids: {'w_12c3d3d', 'new_whale'}
# Duplicate images: ['b1d3d395.jpg', 'cb7f7d57.jpg'], set of Ids: {'w_1e5a146', 'new_whale'}
# Duplicate images: ['334343c9.jpg', 'f1bebb68.jpg'], set of Ids: {'w_cc22f68', 'w_80bae3a'}
# Duplicate images: ['ab988b3e.jpg', 'b23d1ca7.jpg'], set of Ids: {'w_d62128e', 'new_whale'}
# Duplicate images: ['4f6fd0e9.jpg', '8614219d.jpg'], set of Ids: {'w_5570053', 'w_dbd2cff'}
# Duplicate images: ['29c82382.jpg', 'ee1cfa3c.jpg'], set of Ids: {'w_045d9fc', 'new_whale'}
# Duplicate images: ['527ff29a.jpg', 'fb7b0e02.jpg'], set of Ids: {'w_c74ab24', 'new_whale'}
# Duplicate images: ['7236c1f6.jpg', 'dfc81206.jpg'], set of Ids: {'w_41ed8e8', 'new_whale'}
# Duplicate images: ['2e8111df.jpg', '57fe5fbd.jpg'], set of Ids: {'w_3745f59', 'new_whale'}
# Duplicate images: ['41361b5f.jpg', 'd8485b38.jpg'], set of Ids: {'w_63035d1', 'new_whale'}
# Duplicate images: ['1d6cf53b.jpg', 'aa897d21.jpg'], set of Ids: {'w_511c464', 'new_whale'}
# Duplicate images: ['2c9bbea5.jpg', 'f3c1b087.jpg'], set of Ids: {'w_c0560ac', 'new_whale'}
# Duplicate images: ['4123189d.jpg', '637b28a7.jpg'], set of Ids: {'w_efd3f81', 'new_whale'}
# Duplicate images: ['3e91ad0d.jpg', 'f7b4598a.jpg'], set of Ids: {'w_8a4b8ef', 'new_whale'}
# Duplicate images: ['55a53eac.jpg', '717554b6.jpg'], set of Ids: {'w_f660d7d', 'w_6af9dd7'}
# Duplicate images: ['973d410c.jpg', 'e0dda879.jpg'], set of Ids: {'w_d96a0cd', 'new_whale'}
# Duplicate images: ['508958a1.jpg', 'adce1628.jpg'], set of Ids: {'w_22bb9b3', 'new_whale'}
# Duplicate images: ['9bb6f188.jpg', 'e6ffa80c.jpg'], set of Ids: {'w_778ee6e', 'new_whale'}
# Duplicate images: ['44134aec.jpg', '4a640733.jpg'], set of Ids: {'w_49bbc79', 'new_whale'}
# Duplicate images: ['30ca0299.jpg', '75cd5008.jpg'], set of Ids: {'w_f5771d1', 'w_1000f90'}
# Duplicate images: ['41981a88.jpg', '74934a2c.jpg'], set of Ids: {'w_6361632', 'new_whale'}
# Duplicate images: ['76611f14.jpg', 'f2305c60.jpg'], set of Ids: {'w_44cccf6', 'new_whale'}
# Duplicate images: ['bb95262c.jpg', 'fd30f7e6.jpg'], set of Ids: {'w_9b401eb', 'new_whale'}
# Duplicate images: ['81c129dd.jpg', 'b69b0ded.jpg'], set of Ids: {'w_471ae98', 'new_whale'}
# Duplicate images: ['a1751aaa.jpg', 'a8c1fb30.jpg'], set of Ids: {'w_dd60c18', 'new_whale'}
# Duplicate images: ['a300e9ee.jpg', 'ef39639e.jpg'], set of Ids: {'w_1f6e1db', 'new_whale'}
# Duplicate images: ['b1485028.jpg', 'feb1ecd3.jpg'], set of Ids: {'w_b9c9129', 'new_whale'}
# Duplicate images: ['2b3fd959.jpg', '7b12411a.jpg'], set of Ids: {'w_2739d94', 'new_whale'}
# Duplicate images: ['974dc5fc.jpg', '9f32d836.jpg'], set of Ids: {'w_96c141f', 'new_whale'}
# Duplicate images: ['0c11fa0c.jpg', '7f7702dc.jpg'], set of Ids: {'w_53859b2', 'new_whale'}
# Duplicate images: ['37b38907.jpg', '6e856d8b.jpg'], set of Ids: {'w_2fe43c7', 'new_whale'}
# Duplicate images: ['244cd83c.jpg', 'd827fba7.jpg'], set of Ids: {'w_d398969', 'new_whale'}
# Duplicate images: ['3b5c89ac.jpg', '556786d7.jpg'], set of Ids: {'w_ffa78a5', 'new_whale'}
# Duplicate images: ['47d88de7.jpg', 'feb32d26.jpg'], set of Ids: {'w_b17f9ea', 'new_whale'}
# Duplicate images: ['4600ab84.jpg', '83c66c07.jpg'], set of Ids: {'w_cbd271b', 'new_whale'}
# Duplicate images: ['063e62a9.jpg', 'e37e2e2f.jpg'], set of Ids: {'new_whale', 'w_845f7ca'}
# Duplicate images: ['c84489dc.jpg', 'd7eb44e1.jpg'], set of Ids: {'w_7852bd1', 'new_whale'}
# Duplicate images: ['0c35fcb4.jpg', '2d6610b9.jpg'], set of Ids: {'w_7028d77', 'w_f6bca7a'}
# Duplicate images: ['84bd38f3.jpg', 'c398d294.jpg'], set of Ids: {'w_7c18f3c', 'new_whale'}
# Duplicate images: ['2d210495.jpg', 'db1d90b7.jpg'], set of Ids: {'w_715d152', 'new_whale'}
# Duplicate images: ['842686a1.jpg', 'd5d3808d.jpg'], set of Ids: {'w_2c55303', 'new_whale'}
# Duplicate images: ['40d1b9cd.jpg', '4c7d8b01.jpg'], set of Ids: {'new_whale', 'w_e7a238b'}
# Duplicate images: ['6020a141.jpg', '7dea560c.jpg'], set of Ids: {'w_b8fdb8e', 'new_whale'}
# Duplicate images: ['5e1e8352.jpg', 'a971c563.jpg'], set of Ids: {'w_aa3d7b8', 'new_whale'}
# Duplicate images: ['33ec74f3.jpg', 'b45cb8ed.jpg'], set of Ids: {'w_f8e6546', 'new_whale'}
# Duplicate images: ['2b792814.jpg', '56fafc52.jpg'], set of Ids: {'w_d428980', 'w_cd88a48'}
# Duplicate images: ['633af56a.jpg', 'aab0c448.jpg'], set of Ids: {'w_20f86e1', 'new_whale'}
# Duplicate images: ['c3f9e536.jpg', 'cca9cd4e.jpg'], set of Ids: {'w_b7d5069', 'w_da6d50b'}
# Duplicate images: ['487f8abe.jpg', 'bdcb59f8.jpg'], set of Ids: {'w_e61dd6d', 'new_whale'}
# Duplicate images: ['0bfb2b72.jpg', 'eff82e34.jpg'], set of Ids: {'w_19eb1b8', 'new_whale'}
# Duplicate images: ['32880412.jpg', 'b0b78bf6.jpg'], set of Ids: {'w_dfbfe10', 'new_whale'}
# Duplicate images: ['982e82e2.jpg', 'b74e0a23.jpg'], set of Ids: {'w_49308df', 'new_whale'}
# Duplicate images: ['1b37d75e.jpg', '80df837b.jpg'], set of Ids: {'w_c0f3e88', 'new_whale'}
# Duplicate images: ['cebf233a.jpg', 'e90a072d.jpg'], set of Ids: {'w_741861e', 'new_whale'}
# Duplicate images: ['94d5c3ec.jpg', 'b23234f2.jpg'], set of Ids: {'w_a8da4a3', 'new_whale'}
# Duplicate images: ['64566f1b.jpg', 'a9767dd2.jpg'], set of Ids: {'w_95874a5', 'new_whale'}
# Duplicate images: ['71afa981.jpg', '847238a3.jpg'], set of Ids: {'w_813c5be', 'new_whale'}
# Duplicate images: ['3bf857ac.jpg', '52a0de28.jpg'], set of Ids: {'w_c6be61e', 'new_whale'}
# Duplicate images: ['8d19395a.jpg', '90acceb8.jpg'], set of Ids: {'w_d88da6d', 'new_whale'}
# Duplicate images: ['f1b7c15c.jpg', 'ff2d0d82.jpg'], set of Ids: {'w_17ee910', 'new_whale'}
# Duplicate images: ['8904e37f.jpg', '9314677e.jpg'], set of Ids: {'w_f0f0dbb', 'new_whale'}
# Duplicate images: ['aa70c3a4.jpg', 'ba72799e.jpg'], set of Ids: {'w_7185713', 'new_whale'}
# Duplicate images: ['8d9b4a76.jpg', '9f3a9096.jpg'], set of Ids: {'w_32a920b', 'new_whale'}
# Duplicate images: ['bcf56bfe.jpg', 'd71be0d5.jpg'], set of Ids: {'w_1a70685', 'new_whale'}
# Duplicate images: ['2b2eb6e1.jpg', '60b8927d.jpg'], set of Ids: {'w_6737f89', 'new_whale'}
# Duplicate images: ['b158abdc.jpg', 'fe937459.jpg'], set of Ids: {'w_b34793e', 'new_whale'}
# Duplicate images: ['59b5781f.jpg', '8caf404f.jpg'], set of Ids: {'w_bb2d34d', 'new_whale'}
# Duplicate images: ['0031c258.jpg', 'f130cb7d.jpg'], set of Ids: {'w_aae82f8', 'new_whale'}
# Duplicate images: ['28624189.jpg', 'b5f46cf1.jpg'], set of Ids: {'w_bb2d34d', 'new_whale'}
# Duplicate images: ['7ddecfc2.jpg', '8f7cf1d4.jpg'], set of Ids: {'w_9548fcf', 'new_whale'}
# Duplicate images: ['aa0d5462.jpg', 'de10d8a0.jpg'], set of Ids: {'new_whale', 'w_c9111ac'}
# Duplicate images: ['a9baefcc.jpg', 'f7bf8ae9.jpg'], set of Ids: {'w_e54feba', 'new_whale'}
# Duplicate images: ['75412872.jpg', 'bbf6a75b.jpg'], set of Ids: {'w_b4732ef', 'new_whale'}
# Duplicate images: ['1779d2fe.jpg', 'bbfb000c.jpg'], set of Ids: {'w_e30e97f', 'new_whale'}
# Duplicate images: ['3ae20220.jpg', 'b8951041.jpg'], set of Ids: {'w_93e1b76', 'new_whale'}
# Duplicate images: ['83d50b85.jpg', 'e1eba938.jpg'], set of Ids: {'w_91572bb', 'new_whale'}
# Duplicate images: ['4872bc99.jpg', 'cfa397ce.jpg'], set of Ids: {'w_d4b90bf', 'new_whale'}
# Duplicate images: ['2c3e707c.jpg', 'fe3329b4.jpg'], set of Ids: {'w_a837660', 'new_whale'}
# Duplicate images: ['8e6cd7f4.jpg', 'caa04386.jpg'], set of Ids: {'w_97bc172', 'new_whale'}
# Duplicate images: ['549c47d5.jpg', '8aa8e20f.jpg'], set of Ids: {'new_whale', 'w_8a438a4'}
# Duplicate images: ['417fa931.jpg', '54e24354.jpg'], set of Ids: {'w_95874a5', 'new_whale'}
# Duplicate images: ['9c46a373.jpg', 'c6f52c45.jpg'], set of Ids: {'w_09e0cbf', 'new_whale'}
# Duplicate images: ['85040559.jpg', 'e602ccd0.jpg'], set of Ids: {'w_c1b3568', 'new_whale'}
# Duplicate images: ['16dad39c.jpg', '970cf3bc.jpg'], set of Ids: {'w_f87b77b', 'new_whale'}
# Duplicate images: ['3e08fa34.jpg', 'e429da12.jpg'], set of Ids: {'w_d0157fd', 'new_whale'}
# Duplicate images: ['522b1d12.jpg', '902324b0.jpg'], set of Ids: {'w_1f09cdd', 'new_whale'}
# Duplicate images: ['5efb5870.jpg', 'b57f01fe.jpg'], set of Ids: {'w_f672e01', 'new_whale'}
# Duplicate images: ['e7318d2d.jpg', 'e8cf10ce.jpg'], set of Ids: {'w_8717ef3', 'new_whale'}
# Duplicate images: ['0ca843f9.jpg', 'b5573551.jpg'], set of Ids: {'w_5a0d250', 'new_whale'}
# Duplicate images: ['0f550bb8.jpg', 'c081d117.jpg'], set of Ids: {'w_652e069', 'new_whale'}
# Duplicate images: ['6dbafffe.jpg', 'ed9f6964.jpg'], set of Ids: {'w_881f3c4', 'new_whale'}
# Duplicate images: ['48c51cc5.jpg', '9a8496a0.jpg'], set of Ids: {'w_f843c4d', 'w_90201e3'}
# Duplicate images: ['6e26b2fd.jpg', 'c7102d1c.jpg'], set of Ids: {'w_2f6e76c', 'new_whale'}
# Duplicate images: ['687abfb4.jpg', 'b70b16f3.jpg'], set of Ids: {'w_5797d05', 'new_whale'}
# Duplicate images: ['32aba2a8.jpg', '90fa288c.jpg'], set of Ids: {'w_9b401eb', 'new_whale'}
# Duplicate images: ['163e7a25.jpg', 'beba228a.jpg'], set of Ids: {'w_b478c13', 'new_whale'}
# Duplicate images: ['4d9308ae.jpg', '81547d94.jpg'], set of Ids: {'w_ba302c8', 'new_whale'}
# Duplicate images: ['c7bf6ae9.jpg', 'e69e6d59.jpg'], set of Ids: {'w_2fe43c7', 'new_whale'}
# Duplicate images: ['857d2743.jpg', '8bcac806.jpg'], set of Ids: {'w_b6410bc', 'new_whale'}
# Duplicate images: ['70cd3cf2.jpg', 'be9d047d.jpg'], set of Ids: {'w_5c07f42', 'new_whale'}
# Duplicate images: ['151f1e39.jpg', 'b9fe7c00.jpg'], set of Ids: {'w_2f81b85', 'new_whale'}
# Duplicate images: ['74e83810.jpg', 'aaa2cdd3.jpg'], set of Ids: {'w_fe2742d', 'new_whale'}
# Duplicate images: ['1b5feb2a.jpg', '8e3dd01a.jpg'], set of Ids: {'w_8c9ed42', 'new_whale'}
# Duplicate images: ['2f778f6c.jpg', 'bb2a1714.jpg'], set of Ids: {'w_3de676c', 'new_whale'}
# Duplicate images: ['5a3f0084.jpg', '87ec06b2.jpg'], set of Ids: {'w_ad3dd0b', 'new_whale'}
# Duplicate images: ['9529dfe3.jpg', 'e0030e15.jpg'], set of Ids: {'w_f75302f', 'new_whale'}
# Duplicate images: ['1efe5ef7.jpg', 'f5287173.jpg'], set of Ids: {'w_11f6df1', 'new_whale'}
# Duplicate images: ['4398e933.jpg', 'fa2b1d93.jpg'], set of Ids: {'w_c666071', 'new_whale'}
# Duplicate images: ['0e4e6449.jpg', 'c80d3657.jpg'], set of Ids: {'w_63d10a1', 'new_whale'}
# Duplicate images: ['5844f3f2.jpg', '73bbaf2d.jpg'], set of Ids: {'w_94ba67d', 'new_whale'}
# Duplicate images: ['391ae1f9.jpg', '42e24810.jpg'], set of Ids: {'w_06972d2', 'new_whale'}
# Duplicate images: ['c31459be.jpg', 'ec506248.jpg'], set of Ids: {'w_bb2d34d', 'new_whale'}
# Duplicate images: ['626ff3eb.jpg', '802dee44.jpg'], set of Ids: {'w_f115d53', 'new_whale'}
# Duplicate images: ['613cbac6.jpg', '7b2b98f5.jpg'], set of Ids: {'w_64433af', 'new_whale'}
# Duplicate images: ['5b9748b5.jpg', '9e607676.jpg'], set of Ids: {'w_6734e40', 'new_whale'}
# Duplicate images: ['239c83c2.jpg', '73332aa2.jpg'], set of Ids: {'w_54c00ad', 'new_whale'}
# Duplicate images: ['4d64dac6.jpg', 'e42b4e9b.jpg'], set of Ids: {'w_17a2610', 'new_whale'}
# Duplicate images: ['151b97b3.jpg', '2da044f5.jpg'], set of Ids: {'w_fca13e2', 'new_whale'}
# Duplicate images: ['25c9e881.jpg', 'a7a4a18e.jpg'], set of Ids: {'w_5ba417d', 'new_whale'}
# Duplicate images: ['4d11635e.jpg', '79774219.jpg'], set of Ids: {'w_6163581', 'new_whale'}
# Duplicate images: ['64d74ec8.jpg', 'a3132d22.jpg'], set of Ids: {'w_c9e1cdc', 'new_whale'}
# Duplicate images: ['5281c01f.jpg', 'e3074aa4.jpg'], set of Ids: {'w_cb2f78e', 'new_whale'}
# Duplicate images: ['43b43ee2.jpg', 'd804659e.jpg'], set of Ids: {'w_e964ae8', 'new_whale'}
# Duplicate images: ['bd91e244.jpg', 'c941efe9.jpg'], set of Ids: {'w_22bcbd6', 'new_whale'}
# Duplicate images: ['6519746e.jpg', 'd895ed09.jpg'], set of Ids: {'w_1b6d34d', 'new_whale'}
# Duplicate images: ['b7f01086.jpg', 'd60ecdd5.jpg'], set of Ids: {'w_3039e7a', 'new_whale'}
# Duplicate images: ['9eb3291e.jpg', 'db034c12.jpg'], set of Ids: {'w_2ef900c', 'new_whale'}
# Duplicate images: ['71ffa6c5.jpg', 'b8e3edd2.jpg'], set of Ids: {'w_31b020c', 'new_whale'}
# Duplicate images: ['3e4a4574.jpg', '6ecce813.jpg'], set of Ids: {'new_whale', 'w_e63fbbe'}
# Duplicate images: ['7498e803.jpg', 'b855bace.jpg'], set of Ids: {'w_2a9727c', 'new_whale'}
# Duplicate images: ['70a02704.jpg', '8eb5b714.jpg'], set of Ids: {'w_ee17a08', 'new_whale'}
# Duplicate images: ['19d70c47.jpg', 'a80c305c.jpg'], set of Ids: {'w_97bc172', 'new_whale'}
# Duplicate images: ['76a22476.jpg', 'a2166492.jpg'], set of Ids: {'w_cdc21df', 'new_whale'}
# Duplicate images: ['6e29caa7.jpg', 'f7bbc4ee.jpg'], set of Ids: {'w_7133c9d', 'new_whale'}
# Duplicate images: ['33214781.jpg', '44722f31.jpg'], set of Ids: {'w_62c6a8c', 'new_whale'}
# Duplicate images: ['03933dbb.jpg', 'eea93983.jpg'], set of Ids: {'w_18eee6e', 'new_whale'}
# Duplicate images: ['19035b3c.jpg', '71235829.jpg'], set of Ids: {'w_a365757', 'new_whale'}
# Duplicate images: ['2eb590c7.jpg', '941479c5.jpg'], set of Ids: {'w_41a79d7', 'new_whale'}
# Duplicate images: ['1c0a7333.jpg', '71d1dac1.jpg'], set of Ids: {'w_91a96d8', 'new_whale'}
# Duplicate images: ['cba81909.jpg', 'cf0f99d2.jpg'], set of Ids: {'w_d9055d1', 'new_whale'}
# Duplicate images: ['aa56de1b.jpg', 'e1be22bd.jpg'], set of Ids: {'w_83df8d5', 'new_whale'}
# Duplicate images: ['2407e5ff.jpg', '8982cf4f.jpg'], set of Ids: {'w_dcd7a1d', 'new_whale'}
# Duplicate images: ['a1e914d7.jpg', 'd1a1c1c0.jpg'], set of Ids: {'w_a06bdc4', 'new_whale'}
# Duplicate images: ['660e39f4.jpg', '8df52ebd.jpg'], set of Ids: {'w_92be3ca', 'new_whale'}
# Duplicate images: ['5558710f.jpg', '83ebd3ab.jpg'], set of Ids: {'w_6ee7470', 'new_whale'}
# Duplicate images: ['219b9d5b.jpg', 'c7996a54.jpg'], set of Ids: {'w_7028d77', 'new_whale'}
# Duplicate images: ['4f956a19.jpg', '5b4a682d.jpg'], set of Ids: {'w_1a70685', 'new_whale'}
# Duplicate images: ['0d482f6b.jpg', 'ab7916f7.jpg'], set of Ids: {'w_28ce17c', 'new_whale'}
# Duplicate images: ['10807a6e.jpg', '9539a505.jpg'], set of Ids: {'w_62c3998', 'new_whale'}
# Duplicate images: ['3f7a3e4c.jpg', '8234edd0.jpg'], set of Ids: {'w_a67a1bc', 'w_e8a9fb8'}
# Duplicate images: ['2c1df05d.jpg', '50e6f606.jpg'], set of Ids: {'w_41ed8e8', 'new_whale'}
# Duplicate images: ['88f6e371.jpg', 'f796599e.jpg'], set of Ids: {'w_07e92ee', 'new_whale'}
# Duplicate images: ['6395a7f5.jpg', 'ef825832.jpg'], set of Ids: {'w_62c3998', 'new_whale'}
# Duplicate images: ['3a8a29d3.jpg', '7165f410.jpg'], set of Ids: {'w_598b8ab', 'new_whale'}
# Duplicate images: ['8327be2a.jpg', '9fe928f6.jpg'], set of Ids: {'w_b6efe77', 'w_741861e'}
# Duplicate images: ['59becb6c.jpg', 'cc68d9f2.jpg'], set of Ids: {'w_cae7677', 'new_whale'}
# Duplicate images: ['af943b37.jpg', 'b2ffcaca.jpg'], set of Ids: {'w_9ceb05d', 'new_whale'}
# Duplicate images: ['8e8d1b22.jpg', 'bfdddcad.jpg'], set of Ids: {'new_whale', 'w_ab4cae2'}
# Duplicate images: ['2f899d4d.jpg', '46b7dba5.jpg'], set of Ids: {'w_dcb1f2a', 'new_whale'}
# Duplicate images: ['72dedcc9.jpg', 'abbed544.jpg'], set of Ids: {'w_03ed3de', 'new_whale'}
# Duplicate images: ['72469a66.jpg', 'cf46e113.jpg'], set of Ids: {'w_c0d494d', 'new_whale'}
# Duplicate images: ['8504db72.jpg', 'd1b3f470.jpg'], set of Ids: {'w_d89b29e', 'new_whale'}
# Duplicate images: ['2a7f4c7f.jpg', '958db488.jpg'], set of Ids: {'w_ea2385d', 'new_whale'}
# Duplicate images: ['67758056.jpg', '9cd2fa20.jpg'], set of Ids: {'w_d8e752e', 'new_whale'}
# Duplicate images: ['04ad14b2.jpg', 'd4707926.jpg'], set of Ids: {'w_c0d494d', 'new_whale'}
# Duplicate images: ['1933258b.jpg', '9ea6371c.jpg'], set of Ids: {'w_7dee51b', 'new_whale'}
# Duplicate images: ['c6ab6e36.jpg', 'edaff6f0.jpg'], set of Ids: {'new_whale', 'w_76b6f7c'}
# Number of 'new whale' in duplicate images: 174
# Number of duplicates: -174
# Number of _duplicates: 368
